# %%
# %matplotlib inline  
import matplotlib.pyplot as plt   
import pandas as pd
import random
import numpy as np
from tqdm import tqdm
from tqdm import tnrange, tqdm_notebook
from time import sleep
import scipy
import operator
import difflib
import math

from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))  # to make the notebook use the entire width of the browser



try:
    import cPickle as pickle  ##################################
   #it is faster than pickle!
except:
    import pickle
    
import unicodedata
import networkx as nx
import itertools
#import seaborn as sns   ### https://seaborn.pydata.org/tutorial/categorical.html
import time  


import sys

#import plotly.plotly as py


# i only need my credentials if i want to plot online --- and send plots to server (limits per day apply!)
#import plotly.tools as tls
#tls.set_credentials_file(username='juliettapc', api_key='deyNIvtOoDZ5PLmrHlhd')  # my plotly account credentials


#import pygraphviz
#from networkx.drawing.nx_agraph import graphviz_layout




# ########## to be able to plot offline (without sending the plots to the plotly server every time)
# import plotly.offline as offline
# from plotly.graph_objs import *
# from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# init_notebook_mode(connected=True)
# ################



# ##### for getting geolocation data  and to calculate distance between two geolocations
# import requests
# import json
import geopy.distance
# Out:
# <style>.container { width:100% !important; }</style>

# %%
########  csv  users basic attr
path="/home/juliaponcela/at_NICO/Dropbox_collaboration_patterns/Data/Dropbox/"
input_file = 'DROPBOX_basic_user_attr_COMPLETE.csv'
df_user_basic_attr = pd.read_csv(path+input_file, sep=';',na_values=["NAN","-1","null"]) # set header=0 if i wanna pass it my own list of header names
#df_user_basic_attr.drop('Unnamed: 0', axis=1, inplace=True)
print "num. users:",df_user_basic_attr.shape






########  dictionary folder list members
pickle_name='/home/juliaponcela/at_NICO/Dropbox_collaboration_patterns/Results/dict_folder_id_list_users_COMPLETE.pickle'
with open(pickle_name, 'rb') as handle:
    dict_folder_id_list_users = pickle.load(handle) 
print len(dict_folder_id_list_users.keys())


########  dictionary user list folders
pickle_name='/home/juliaponcela/at_NICO/Dropbox_collaboration_patterns/Results/dict_user_id_list_folders_COMPLETE.pickle'
with open(pickle_name, 'rb') as handle:
    dict_user_id_list_folders = pickle.load(handle) 
print len(dict_folder_id_list_users.keys())






#########  csv  all act aggr by date
path = "/home/juliaponcela/at_NICO/Dropbox_collaboration_patterns/Data/Dropbox/"
input_file = 'DROPBOX_only_activity_aggr_by_date_COMPLETE.csv'
df_all_act = pd.read_csv(path+input_file, sep=',',na_values=["NAN","-1","null"], parse_dates=['folder_creation_date','date'], nrows=1000000) # set header=0 if i wanna pass it my own list of header names
df_all_act.drop('Unnamed: 0', axis=1, inplace=True)
print "num. users:",len(df_all_act.user_id.unique()),df_all_act.shape    # 200000 (3072489, 8)
  
df_all_act=df_all_act.replace('nan', np.nan)  ## for some reason, there are diff nomenclatures for NANs, and it is not interpreting them correctly when reading the file 
df_all_act=df_all_act.replace('NAN', np.nan)
df_all_act=df_all_act.replace('NaN', np.nan)
df_all_act=df_all_act.replace('-1', np.nan)
df_all_act=df_all_act.replace('', np.nan)




#convert the date columns from str to datetime    (for some reason, parsing when i read it does nothing)
df_all_act['date'] = pd.to_datetime(df_all_act['date'], errors='coerce')
df_all_act['folder_creation_date'] = pd.to_datetime(df_all_act['folder_creation_date'], errors='coerce')

df_all_act_no_NANs= df_all_act[df_all_act.date.notnull()]    
print "after removing rows without dates:\n  num. users:",len(df_all_act_no_NANs.user_id.unique()),df_all_act_no_NANs.shape    # 400000  (5141758, 7)
# Out:
# num. users: (438300, 16)
# 519045
# 519045
# num. users: 61984 (1000000, 7)
# after removing rows without dates:
#   num. users: 25093 (862876, 7)

# %%
df_user_basic_attr.head()
# Out:
#      user_id  email_domain                              field  \
# 0    76604.0       unc.edu                         humanities
# 1   130678.0  columbia.edu                            science
# 2   178708.0   cornell.edu  business econ finances government
# 3  1148983.0    cs.cmu.edu                         humanities
# 4   278109.0    cs.cmu.edu                         humanities
#
#   group_total_publ group_num_papers_last group_num_citations  \
# 0              NaN                   NaN                 NaN
# 1          1.0-2.0               0.0-1.0            1.0-30.0
# 2              NaN                   NaN                 NaN
# 3              NaN                   NaN                 NaN
# 4              NaN                   NaN                 NaN
#
#                                University_name        Country  world_ranking  \
# 0  university of north carolina at chapel hill  United States           40.0
# 1                          columbia university  United States            6.0
# 2                           cornell university  United States           10.0
# 3                   carnegie mellon university  United States           61.0
# 4                   carnegie mellon university  United States           61.0
#
#    national_ranking career_stage  category_total_publ  \
# 0              25.0          NaN                  NaN
# 1               4.0           jr                  1.0
# 2               8.0          NaN                  NaN
# 3              39.0          NaN                  NaN
# 4              39.0          NaN                  NaN
#
#    category_total_last_auth  category_total_cit  \
# 0                       NaN                 NaN
# 1                       1.0                 2.0
# 2                       NaN                 NaN
# 3                       NaN                 NaN
# 4                       NaN                 NaN
#
#                                    geoloc
# 0              (35.9049122, -79.0469134)
# 1         (40.8075355, -73.9625727) 10027
# 2         (42.4534492, -76.4735027) 14850
# 3  (40.4428081, -79.94301279999999) 15213
# 4  (40.4428081, -79.94301279999999) 15213

# %%
#from hurry.filesize import size
#import hurry
import humanize
object_bytes=sys.getsizeof(df_all_act)
#print object_bytes, size(object_bytes)

print object_bytes, humanize.naturalsize(object_bytes)
# Out:
# 611224985 611.2 MB

# %%
#dict_user_id_tot_act
#df_user_basic_attr # user_id	email_domain	field	new_group_total_pubs	new_group_num_papers_last	new_group_num_citations	University_name	Country	world_ranking	national_ranking
#dict_folder_id_list_users
#dict_user_id_list_folders

#df_all_act    #date	folder_creation_date	folder_id	num_adds	num_dels	num_edits	user_id
#df_user_basic_attr    # user_id	email_domain	field	group_total_publ	group_num_papers_last	group_num_citations	University_name	
#                      Country	world_ranking	national_ranking	career_stage	category_total_publ	category_total_last_auth	category_total_cit

# %%
# path = "/home/juliaponcela/at_NICO/Dropbox_collaboration_patterns/Data/Dropbox/"
# input_file = 'new_sorted_no_duplicatesprocessed_timestaps_PARTIAL.csv'
# #input_file = 'Dropbox_datafile_may22_2017_modified_added_univ_country_geolocation_RUCC_population_density_when_available_career_stage_GINI_folder_act_categories.csv'
# df = pd.read_csv(path+input_file, sep=';',na_values=["NAN","-1","null"],low_memory=False, parse_dates=['folder_creation_date','date_last_change']) # set header=0 if i wanna pass it my own list of header names
# df.drop('Unnamed: 0', axis=1, inplace=True)



# print df.shape

# %%
def remove_nans(lista):
   # print "\n",lista
    aux_lista=[]
    for i in range(len(lista)):    
       # print lista[i]
        try:
            if np.isnan(lista[i]) == True:  # (when nan):   # OJO!!! NO SIRVE SI HAGO: if lista[I]== np.nan   :(   !!!
                pass#print "nan found"
            else: # (when not-nan):           
                aux_lista.append(lista[i])
            #print "no problem"
        except : ## whenever it is a STR            
            pass            
            
            
    #print aux_lista   
    return aux_lista


############################3



def remove_nans_for_strings(lista):
   # print "\n",lista
    aux_lista=[]
    for i in range(len(lista)):    
       # print lista[i]
        try:
            if np.isnan(lista[i]) == True:  # (when nan):   # OJO!!! NO SIRVE SI HAGO: if lista[I]== np.nan   :(   !!!
                pass#print "nan found"
            else: # (when not-nan):           
                aux_lista.append(lista[i])
            #print "no problem"
        except : ## whenever it is a STR            
             aux_lista.append(lista[i])#pass             
            
            
    #print aux_lista   
    return aux_lista




###############

def remove_nans_replace_by_zeros(lista):
   # print "\n",lista
    aux_lista=[]
    for i in range(len(lista)):    
       # print lista[i]
        try:
            if np.isnan(lista[i]) == True:  # (when nan):   # OJO!!! NO SIRVE SI HAGO: if lista[I]== np.nan   :(   !!!
                aux_lista.append(0.)        #pass#print "nan found"
            else: # (when not-nan):           
                aux_lista.append(float(lista[i]))
            #print "no problem"
        except : ## whenever it is a STR            
            pass             
            
            
    #print aux_lista   
    return aux_lista




###### get dict with  folder_id lifespan:
def remove_nans_replace_intervals_with_starting_value(lista):
    #print "\n",lista
    aux_lista=[]
    for i in range(len(lista)):    
       # print lista[i]
        try:
            if np.isnan(lista[i]) == True:  # (when/ nan):   # OJO!!! NO SIRVE SI HAGO: if lista[I]== np.nan   :(   !!!
                pass#print "nan found"
        except TypeError: # (when not-nan):
            #print lista[i]   
            try:  
                aux_lista.append(float(lista[i]))
                #print "no problem"
            except ValueError:  # sometimes, the ranking is 75-82
                #print "issue found"
                value=lista[i]
#                 v1=float(value.split("-")[0])
#                 v2=float(value.split("-")[1])
                
                new_value=float(value.split("-")[0])#np.median([v1,v2])  
                aux_lista.append(new_value)
            
    #print aux_lista   
    return aux_lista


#############



def gini(old_list_of_values):
    
    list_of_values=[]
    for item in old_list_of_values:
        try:
            int(item) # if it is a NAN, it with fail
            list_of_values.append(item)
        except:
            pass
    
   # print list_of_values
    sorted_list = sorted(list_of_values)
    height, area = 0, 0
    for value in sorted_list:
        height += value
        area += height - value / 2.
    fair_area = height * len(list_of_values) / 2.
    try:
        return (fair_area - area) / fair_area
    except ZeroDivisionError:
#         print "problems with:",list_of_values   # if lista=[0,0,0]  or [0]
#         raw_input()
        return np.nan


##############


def  effective_num(lista_values):  # i can use it for the effective number of members in a folder, by activity, or the effective number of folders for a user, also by activity
    
     # first, i need to remove the zeros, because i cant do the log(0), but i can remove them, they dont count as effective members
    
    
    cont_num_nonzero_items=0
    H=0.
    tot_sum=float(sum(lista_values))
    for item in lista_values:
        if item >0:
            aux= item/tot_sum * np.log2( item/tot_sum)
            H += aux
            cont_num_nonzero_items +=1
            
    H = -1.0 * H
    
    eff_number = np.power(2.0, H)
    
    if cont_num_nonzero_items ==0:   # if the list of act is [0] then i want the eff. number to be 0, not 1
        eff_number =0
    
    return eff_number

# %%
              
###########  i get dict for the user_id vs attr

def grouping_user(user_id, df_select_user_act, df_select_user_attr, list_folders, dict_user_id_user_attr):
    
#     print df_select_user_act
    
    dict_user_id_user_attr[user_id]={}
    dict_user_id_user_attr[user_id]["number_folders"]=len(list_folders)
   
#     print "num. folders:", len(list_folders)
    
    
   #### FALTA: dict_user_id_user_attr[user_id]["mean_folder_lifespan"]=np.mean(list(input_df.folder_lifespan))
    
 ######## FALTA: catalogar users are lead or not en cada folder (el que mas trabajo hace)
 
    
    dict_folder_id_tot_act={}
    list_tot_act_across_folders=[]
    for folder_id in list_folders:
    
        df_select= df_select_user_act[df_select_user_act['folder_id']== folder_id ]
        
        num_adds=sum(remove_nans_replace_by_zeros(list(df_select.num_adds))) # for activity records, NAN = 0
        num_edits=sum(remove_nans_replace_by_zeros(list(df_select.num_edits)))
        num_deletes=sum(remove_nans_replace_by_zeros(list(df_select.num_dels)))
        act=num_adds+num_edits+num_deletes
        
        list_tot_act_across_folders.append(act)
     
        dict_folder_id_tot_act[folder_id]=act
    
    
    
    dict_user_id_user_attr[user_id]["gini_act_across_folders"]=gini(remove_nans(list_tot_act_across_folders))
    dict_user_id_user_attr[user_id]["eff_num_folders"]=effective_num(remove_nans(list_tot_act_across_folders))
   


#     avg_work_per_folder=np.mean(list_tot_act_across_folders)
#     dict_folder_id_above_avg_work={}    
#     for folder_id in list_folders:
#         dict_folder_id_above_avg_work[folder_id]=0
#         if dict_folder_id_tot_act[folder_id] > avg_work_per_folder:
#             dict_folder_id_above_avg_work[folder_id]=1
    
#     dict_user_id_user_attr[user_id]["folders_above_avg"]=dict_folder_id_above_avg_work
        
        
    
    try:
        univ_ranking=float(df_select_user_attr.world_ranking.iloc[0])
    except ValueError:  # if 101-150
        univ_ranking=float(df_select_user_attr.world_ranking.iloc[0].split("-")[0])
    dict_user_id_user_attr[user_id]["user_univ_ranking"]=univ_ranking
    
        
    
    tot_num_adds=sum(remove_nans_replace_by_zeros(list(df_select_user_act.num_adds)))  # for activity records, NAN = 0
    dict_user_id_user_attr[user_id]["user_tot_num_adds"]=tot_num_adds
    
    
    tot_num_edits=sum(remove_nans_replace_by_zeros(list(df_select_user_act.num_edits)))
    dict_user_id_user_attr[user_id]["user_tot_num_edits"]=tot_num_edits
    
    
    tot_num_deletes=sum(remove_nans_replace_by_zeros(list(df_select_user_act.num_dels)))
    dict_user_id_user_attr[user_id]["user_tot_num_deletes"]=tot_num_deletes
 
    
    tot_act=tot_num_adds+tot_num_edits+tot_num_deletes
    dict_user_id_user_attr[user_id]["user_tot_act"]=tot_act

    
    
     
    
  

    dict_user_id_user_attr[user_id]["field"]=df_select_user_attr.field.iloc[0]   
    dict_user_id_user_attr[user_id]["Country"]=df_select_user_attr.Country.iloc[0]   
    dict_user_id_user_attr[user_id]["University_name"]=df_select_user_attr.University_name.iloc[0]   
    dict_user_id_user_attr[user_id]["career_stage"]=df_select_user_attr.career_stage.iloc[0]   
    dict_user_id_user_attr[user_id]["category_total_publ"]=df_select_user_attr.category_total_publ.iloc[0]        
    dict_user_id_user_attr[user_id]["category_total_last_auth"]=df_select_user_attr.category_total_last_auth.iloc[0]                
    dict_user_id_user_attr[user_id]["category_total_cit"]=df_select_user_attr.category_total_cit.iloc[0]               
    dict_user_id_user_attr[user_id]["email_domain"]=df_select_user_attr.email_domain.iloc[0]   
    dict_user_id_user_attr[user_id]["geoloc"]=df_select_user_attr.geoloc.iloc[0]   
    dict_user_id_user_attr[user_id]["group_num_citations"]=df_select_user_attr.group_num_citations.iloc[0]   
    dict_user_id_user_attr[user_id]["group_num_papers_last"]=df_select_user_attr.group_num_papers_last.iloc[0]   
    dict_user_id_user_attr[user_id]["group_total_publ"]=df_select_user_attr.group_total_publ.iloc[0]       
    dict_user_id_user_attr[user_id]["national_ranking"]=df_select_user_attr.national_ranking.iloc[0]   
    dict_user_id_user_attr[user_id]["world_ranking"]=df_select_user_attr.world_ranking.iloc[0]   
    dict_user_id_user_attr[user_id]["user_id"]=df_select_user_attr.user_id.iloc[0]   


    
    
    
    ########## user's active period
    act_period=0   # because the creation date of most folders is years before our observation period        
    try:       
        act_period= (df_select_user_act.date.iloc[-1] -  df_select_user_act.date.iloc[0]).days +1
    except  AttributeError:  # in case the last dates happen to be NAN
    
        cont=1
        index=-2
        while cont <= len(df_select_user_act) :
            try:
                act_period= (df_select_user_act.date.iloc[index] -  df_select_user_act.date.iloc[0]).days +1               
                cont = 10000000
            except : 
                index -=1

            cont +=1          
                                                            
    dict_user_id_user_attr[user_id]["act_period"]=act_period    
    
    
    dict_user_id_user_attr[user_id]["overall_num_active_days"]=len(df_select_user_act.date.dropna().unique())   
        
     
        
        
    ######### user's gini by days present in each foler, and eff. number of folders by days present    
    list_days_present_folders=[]
    for folder_id in list_folders:
        
        df_act_folder= df_select_user_act[df_select_user_act['folder_id'] == folder_id]                                   
        num_days= len(df_act_folder.date.dropna().unique())                       
        list_days_present_folders.append(num_days)                
        
    dict_user_id_user_attr[user_id]["gini_num_days_present_over_folders"]=gini(remove_nans(list_days_present_folders))   
    dict_user_id_user_attr[user_id]["eff_num_folders_by_days_present"]=effective_num(remove_nans(list_days_present_folders))
    
        
    

      
    
    
    ############ user's burstiness and avg interevent time
    if len(df_select_user_act)>2:        
        
        #print 
        #print df_select_folder_act
        list_deltas= ( df_select_user_act.date - df_select_user_act.date.shift() ).fillna(0)
        lista_interevent_times=[x.days for x in list_deltas][1:]      # the first delta time is always zero because it comes from comparing to nan when shifting the column


       # print lista_interevent_times
        m1=np.mean(lista_interevent_times)
        s1=np.std(lista_interevent_times)

        burstiness= (s1-m1)/(s1+m1)
        dict_user_id_user_attr[user_id]["burstiness"]= burstiness
        dict_folder_id_folder_attr[folder_id]["avg_interevent_time"]= np.mean(lista_interevent_times)
       
       
    else:
        dict_user_id_user_attr[user_id]["burstiness"]=np.nan
        dict_user_id_user_attr[user_id]["avg_interevent_time"]= np.nan

    
    
                    
    
    ###### fract of days when the user multitasks
    cont_simult=0.

    for date in df_select_user_act.date.dropna().unique():
        
        df_select_date = df_select_user_act[df_select_user_act['date'] == date]
        num_folders=len(df_select_date.folder_id.dropna().unique())
        if num_folders >1:
             cont_simult +=1.
    
    try:
        dict_user_id_user_attr[user_id]["frac_multitasking_days_overall"] = cont_simult /  dict_user_id_user_attr[user_id]["act_period"]  # if 0 active days
    except ZeroDivisionError:
        dict_user_id_user_attr[user_id]["frac_multitasking_days_overall"] = np.nan        
        
    try:    
        dict_user_id_user_attr[user_id]["frac_multitasking_days_over_active_days"] = cont_simult /  dict_user_id_user_attr[user_id]["overall_num_active_days"]
    except ZeroDivisionError:
        dict_user_id_user_attr[user_id]["frac_multitasking_days_over_active_days"] = np.nan
    
    
    
    
    
    
    
    
    
 
#########################

    
    
dict_user_id_user_attr={}
cont =0
for user_id in tqdm_notebook(dict_user_id_list_folders):
    
    #print "\n\n",user_id
    list_folders=dict_user_id_list_folders[user_id]
    
    df_select_user_attr=df_user_basic_attr[df_user_basic_attr['user_id'] == user_id]         
    df_select_user_act=df_all_act[df_all_act['user_id']==user_id].sort_values(by=['folder_id', 'date'])
    
    #if len(df_select_user_act)>0:
    grouping_user(user_id, df_select_user_act, df_select_user_attr, list_folders, dict_user_id_user_attr)    # i call this function that modifies the main dict         
            
    
    cont +=1
    if cont > 1000:
        break
    

print "done"

    
 

### parche para arreglar valores sin sentido
for user_id in dict_user_id_user_attr:
    if (dict_user_id_user_attr[user_id]['burstiness'] >1.0 )  or (dict_user_id_user_attr[user_id]['burstiness'] <-1.0) :
        dict_user_id_user_attr[user_id]['burstiness'] = np.nan
        
    if (dict_user_id_user_attr[user_id]['frac_multitasking_days_overall'] >1.0 )  or (dict_user_id_user_attr[user_id]['frac_multitasking_days_overall'] <-1.0) :
        dict_user_id_user_attr[user_id]['frac_multitasking_days_overall'] = np.nan
        
        
    if dict_user_id_user_attr[user_id]['act_period'] < 0.:
        dict_user_id_user_attr[user_id]['act_period'] = -1.*dict_user_id_user_attr[user_id]['act_period']
        
        
    if dict_user_id_user_attr[user_id]['avg_interevent_time'] < 0.:
        dict_user_id_user_attr[user_id]['avg_interevent_time'] = -1.*dict_user_id_user_attr[user_id]['avg_interevent_time']

    
    
    
    
    

pickle_name='/home/juliaponcela/at_NICO/Dropbox_collaboration_patterns/Results/new_dict_user_id_user_attr_PARTIAL.pickle'
with open(pickle_name, 'wb') as handle:
    pickle.dump(dict_user_id_user_attr, handle)
print "written:", pickle_name



df_from_dict = pd.DataFrame.from_dict(dict_user_id_user_attr,orient='index')
#df_from_dict['user_id'] = df_from_dict.index
df_from_dict.to_csv(pickle_name.strip("dict_").strip(".pickle")+".csv", sep=';')
print "written:", pickle_name.strip("dict_").strip(".pickle")+".csv"
# Out:
# [0] <type 'int'>
#   date folder_creation_date     folder_id  num_adds  num_dels  num_edits  \
# 0  NaT           2016-12-07  1.369113e+09       NaN       NaN        NaN
#
#        user_id
# 0  629145600.0
#
# done
# written: /home/juliaponcela/at_NICO/Dropbox_collaboration_patterns/Results/new_dict_user_id_user_attr_PARTIAL.pickle
# written: /home/juliaponcela/at_NICO/Dropbox_collaboration_patterns/Results/new_dict_user_id_user_attr_PARTIAL.csv

# %%
dict_user_id_user_attr#[629145600]

# 629145600.0: 
# {'Country': 'United States',
#  'University_name': 'cornell university',
#  'act_period': 0,
#  'avg_interevent_time': nan,
#  'burstiness': nan,
#  'career_stage': nan,
#  'category_total_cit': nan,
#  'category_total_last_auth': nan,
#  'category_total_publ': nan,
#  'eff_num_folders': 0,
#  'eff_num_folders_by_days_present': 0,
#  'email_domain': 'cornell.edu',
#  'field': nan,
#  'folders_above_avg': {1369112819.0: 0},
#  'geoloc': '(42.4534492, -76.4735027) 14850',
#  'gini_act_across_folders': nan,
#  'gini_num_days_present_over_folders': nan,
#  'group_num_citations': nan,
#  'group_num_papers_last': nan,
#  'group_total_publ': nan,
#  'national_ranking': 8.0,
#  'number_folders': 1,
#  'user_id': 629145600.0,
#  'user_tot_act': 0.0,
#  'user_tot_num_adds': 0.0,
#  'user_tot_num_deletes': 0.0,
#  'user_tot_num_edits': 0.0,
#  'user_univ_ranking': 10.0,
#  'world_ranking': 10.0}
# Out:
# {629145600.0: {'Country': 'United States',
#   'University_name': 'cornell university',
#   'act_period': 0,
#   'avg_interevent_time': nan,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'cornell.edu',
#   'field': nan,
#   'folders_above_avg': {1369112819.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(42.4534492, -76.4735027) 14850',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 8.0,
#   'number_folders': 1,
#   'overall_num_active_days': 0,
#   'user_id': 629145600.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 10.0,
#   'world_ranking': 10.0},
#  76021761.0: {'Country': 'United States',
#   'University_name': 'university of southern california',
#   'act_period': 0,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'usc.edu',
#   'field': nan,
#   'folders_above_avg': {61831821.0: 0, 154962480.0: 0, 440061841.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(34.0223519, -118.285117) 90007',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 34.0,
#   'number_folders': 3,
#   'overall_num_active_days': 0,
#   'user_id': 76021761.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 51.0,
#   'world_ranking': 51.0},
#  168296789.0: {'Country': 'United Kingdom',
#   'University_name': 'university of manchester',
#   'act_period': 0,
#   'avg_interevent_time': nan,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'manchester.ac.uk',
#   'field': nan,
#   'folders_above_avg': {647749835.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(53.4668498, -2.2338837) M13 9PL',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 6.0,
#   'number_folders': 1,
#   'overall_num_active_days': 0,
#   'user_id': 168296789.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 67.0,
#   'world_ranking': 67.0},
#  78645249.0: {'Country': 'United Kingdom',
#   'University_name': 'oxford university press',
#   'act_period': 0,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'oup.com',
#   'field': nan,
#   'folders_above_avg': {186986105.0: 0,
#    318819496.0: 0,
#    443543144.0: 0,
#    749252747.0: 0,
#    828285682.0: 0,
#    961999076.0: 0,
#    1002571555.0: 0,
#    1060803911.0: 0,
#    1374889039.0: 0,
#    1379380658.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(51.7583812, -1.26544) OX2 6DP',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': nan,
#   'number_folders': 10,
#   'overall_num_active_days': 0,
#   'user_id': 78645249.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': nan,
#   'world_ranking': nan},
#  524288009.0: {'Country': 'United States',
#   'University_name': 'university of minnesota ',
#   'act_period': 0,
#   'avg_interevent_time': nan,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'umn.edu',
#   'field': nan,
#   'folders_above_avg': {1124357816.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(44.97399, -93.2277285) 55455',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': nan,
#   'number_folders': 1,
#   'overall_num_active_days': 0,
#   'user_id': 524288009.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': nan,
#   'world_ranking': nan},
#  120635403.0: {'Country': 'United States',
#   'University_name': 'cornell university',
#   'act_period': 527,
#   'burstiness': 0.9366967888710761,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 1.5428836899522751,
#   'eff_num_folders_by_days_present': 2.2970907519728327,
#   'email_domain': 'cornell.edu',
#   'field': nan,
#   'folders_above_avg': {209055221.0: 0,
#    227332528.0: 0,
#    232935373.0: 0,
#    246945841.0: 0,
#    598284246.0: 1,
#    917364847.0: 0,
#    1018835125.0: 0,
#    1374219615.0: 0},
#   'frac_multitasking_days_over_active_days': 0.24932975871313673,
#   'frac_multitasking_days_overall': 0.17647058823529413,
#   'geoloc': '(42.4534492, -76.4735027) 14850',
#   'gini_act_across_folders': 0.8367517533844397,
#   'gini_num_days_present_over_folders': 0.7727754237288136,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 8.0,
#   'number_folders': 8,
#   'overall_num_active_days': 373,
#   'user_id': 120635403.0,
#   'user_tot_act': 6131.0,
#   'user_tot_num_adds': 817.0,
#   'user_tot_num_deletes': 395.0,
#   'user_tot_num_edits': 4919.0,
#   'user_univ_ranking': 10.0,
#   'world_ranking': 10.0},
#  38797324.0: {'Country': 'United States',
#   'University_name': 'university of arizona',
#   'act_period': 0,
#   'avg_interevent_time': nan,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'email.arizona.edu',
#   'field': nan,
#   'folders_above_avg': {687345579.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(32.2318851, -110.9501094) 85721',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 42.0,
#   'number_folders': 1,
#   'overall_num_active_days': 0,
#   'user_id': 38797324.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 68.0,
#   'world_ranking': 68.0},
#  18876429.0: {'Country': 'United States',
#   'University_name': 'stanford university',
#   'act_period': 0,
#   'burstiness': 0.24444018827184283,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 1.0,
#   'eff_num_folders_by_days_present': 1.0,
#   'email_domain': 'stanford.edu',
#   'field': nan,
#   'folders_above_avg': {265920754.0: 0, 1037982191.0: 1},
#   'frac_multitasking_days_over_active_days': 0.0,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(37.4274745, -122.169719) 94305',
#   'gini_act_across_folders': 0.5,
#   'gini_num_days_present_over_folders': 0.5,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 2.0,
#   'number_folders': 2,
#   'overall_num_active_days': 21,
#   'user_id': 18876429.0,
#   'user_tot_act': 900.0,
#   'user_tot_num_adds': 246.0,
#   'user_tot_num_deletes': 110.0,
#   'user_tot_num_edits': 544.0,
#   'user_univ_ranking': 2.0,
#   'world_ranking': 2.0},
#  460326926.0: {'Country': 'United States',
#   'University_name': 'university of houston',
#   'act_period': 0,
#   'burstiness': nan,
#   'career_stage': 'sr',
#   'category_total_cit': 5.0,
#   'category_total_last_auth': 4.0,
#   'category_total_publ': 5.0,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'uh.edu',
#   'field': 'science',
#   'folders_above_avg': {276406589.0: 0, 930403489.0: 0, 1225480272.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(29.7199489, -95.3422334) 77004',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': '1183.0-146545.0',
#   'group_num_papers_last': '18.0-1216.0',
#   'group_total_publ': '56.0-1350.0',
#   'national_ranking': 80.0,
#   'number_folders': 3,
#   'overall_num_active_days': 0,
#   'user_id': 460326926.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 184.0,
#   'world_ranking': 184.0},
#  411043858.0: {'Country': 'Canada',
#   'University_name': 'university of calgary',
#   'act_period': 0,
#   'avg_interevent_time': nan,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'haskayne.ucalgary.ca',
#   'field': nan,
#   'folders_above_avg': {1133683194.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(51.0781599, -114.1358007) T2N 1N4',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 8.0,
#   'number_folders': 1,
#   'overall_num_active_days': 0,
#   'user_id': 411043858.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 167.0,
#   'world_ranking': 167.0},
#  601882643.0: {'Country': 'United States',
#   'University_name': 'university of southern california',
#   'act_period': 0,
#   'avg_interevent_time': nan,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'med.usc.edu',
#   'field': nan,
#   'folders_above_avg': {1303425995.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(34.0223519, -118.285117) 90007',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 34.0,
#   'number_folders': 1,
#   'overall_num_active_days': 0,
#   'user_id': 601882643.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 51.0,
#   'world_ranking': 51.0},
#  12582933.0: {'Country': 'United States',
#   'University_name': 'university of south florida',
#   'act_period': 0,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'mail.usf.edu',
#   'field': nan,
#   'folders_above_avg': {139867400.0: 0, 241513280.0: 0, 596069344.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(28.0587031, -82.41385389999999) 33620',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 83.0,
#   'number_folders': 3,
#   'overall_num_active_days': 0,
#   'user_id': 12582933.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 190.0,
#   'world_ranking': 190.0},
#  20971543.0: {'Country': 'United States',
#   'University_name': 'state university of new york at fredonia',
#   'act_period': 0,
#   'avg_interevent_time': nan,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'fredonia.edu',
#   'field': nan,
#   'folders_above_avg': {116339859.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(42.4538665, -79.34036329999999) 14063',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': nan,
#   'number_folders': 1,
#   'overall_num_active_days': 0,
#   'user_id': 20971543.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': nan,
#   'world_ranking': nan},
#  648019993.0: {'Country': 'United States',
#   'University_name': 'chapman university',
#   'act_period': 0,
#   'avg_interevent_time': nan,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'chapman.edu',
#   'field': nan,
#   'folders_above_avg': {986517141.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(33.7933476, -117.8513503) 92866',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': nan,
#   'number_folders': 1,
#   'overall_num_active_days': 0,
#   'user_id': 648019993.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': nan,
#   'world_ranking': nan},
#  12582939.0: {'Country': 'United States',
#   'University_name': 'university of california los angeles',
#   'act_period': 510,
#   'burstiness': 0.80588531897125759,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 8.3838220776526331,
#   'eff_num_folders_by_days_present': 12.418834326140971,
#   'email_domain': 'lifesci.ucla.edu',
#   'field': nan,
#   'folders_above_avg': {20831750.0: 1,
#    20831771.0: 0,
#    20831781.0: 1,
#    20831806.0: 1,
#    20831827.0: 0,
#    20831846.0: 0,
#    20831879.0: 0,
#    21361414.0: 0,
#    23332716.0: 0,
#    28154637.0: 0,
#    31485287.0: 0,
#    36468571.0: 0,
#    69975874.0: 0,
#    95401820.0: 0,
#    95401876.0: 0,
#    95403459.0: 0,
#    95413820.0: 0,
#    107217364.0: 0,
#    107830458.0: 0,
#    128522982.0: 0,
#    128523095.0: 1,
#    128523151.0: 0,
#    137482054.0: 0,
#    151216495.0: 0,
#    152735407.0: 0,
#    156053018.0: 0,
#    188660471.0: 0,
#    196426472.0: 0,
#    233116059.0: 0,
#    298356863.0: 1,
#    305987184.0: 0,
#    309293626.0: 1,
#    318322001.0: 0,
#    401783593.0: 0,
#    408991588.0: 0,
#    496794536.0: 1,
#    538718042.0: 0,
#    542583703.0: 0,
#    661736142.0: 0,
#    661934628.0: 0,
#    688427754.0: 1,
#    705769793.0: 0,
#    759282751.0: 0,
#    853978083.0: 0,
#    873891043.0: 0,
#    929876110.0: 0,
#    949127981.0: 0,
#    1044806127.0: 1,
#    1045388292.0: 0,
#    1139325900.0: 0,
#    1190411486.0: 0,
#    1252458597.0: 0,
#    1319171353.0: 0,
#    1327120749.0: 0,
#    1347505430.0: 0},
#   'frac_multitasking_days_over_active_days': 0.40397350993377484,
#   'frac_multitasking_days_overall': 0.23921568627450981,
#   'geoloc': '(34.068921, -118.4451811) 90095',
#   'gini_act_across_folders': 0.8797433873883048,
#   'gini_num_days_present_over_folders': 0.830258401392422,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 12.0,
#   'number_folders': 55,
#   'overall_num_active_days': 302,
#   'user_id': 12582939.0,
#   'user_tot_act': 3571.0,
#   'user_tot_num_adds': 2213.0,
#   'user_tot_num_deletes': 911.0,
#   'user_tot_num_edits': 447.0,
#   'user_univ_ranking': 15.0,
#   'world_ranking': 15.0},
#  158337053.0: {'Country': 'United States',
#   'University_name': 'university of pennsylvania',
#   'act_period': 0,
#   'avg_interevent_time': nan,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'uphs.upenn.edu',
#   'field': 'medicine dentistry nursing pharmacology',
#   'folders_above_avg': {253446436.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(39.9522188, -75.1932137) 19104',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 11.0,
#   'number_folders': 1,
#   'overall_num_active_days': 0,
#   'user_id': 158337053.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 14.0,
#   'world_ranking': 14.0},
#  20971550.0: {'Country': 'United States',
#   'University_name': 'university of delaware',
#   'act_period': 29,
#   'burstiness': 0.0050506338833466256,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 1.0750614142859471,
#   'eff_num_folders_by_days_present': 1.3322056912494478,
#   'email_domain': 'udel.edu',
#   'field': nan,
#   'folders_above_avg': {1318936527.0: 1, 1330451777.0: 0},
#   'frac_multitasking_days_over_active_days': 0.09090909090909091,
#   'frac_multitasking_days_overall': 0.034482758620689655,
#   'geoloc': '(39.6779504, -75.7506114) 19716',
#   'gini_act_across_folders': 0.4863013698630137,
#   'gini_num_days_present_over_folders': 0.4166666666666667,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 109.0,
#   'number_folders': 2,
#   'overall_num_active_days': 11,
#   'user_id': 20971550.0,
#   'user_tot_act': 73.0,
#   'user_tot_num_adds': 27.0,
#   'user_tot_num_deletes': 3.0,
#   'user_tot_num_edits': 43.0,
#   'user_univ_ranking': 281.0,
#   'world_ranking': 281.0},
#  55576608.0: {'Country': 'United States',
#   'University_name': 'university of colorado boulder',
#   'act_period': 0,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'colorado.edu',
#   'field': nan,
#   'folders_above_avg': {128790127.0: 0,
#    239337201.0: 0,
#    502642274.0: 0,
#    629158699.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(40.00758099999999, -105.2659417) 80309',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 37.0,
#   'number_folders': 4,
#   'overall_num_active_days': 0,
#   'user_id': 55576608.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 54.0,
#   'world_ranking': 54.0},
#  271583265.0: {'Country': 'United States',
#   'University_name': 'university of kansas medical center',
#   'act_period': 19,
#   'burstiness': -0.2857142857142857,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 1.0,
#   'eff_num_folders_by_days_present': 1.0,
#   'email_domain': 'kumc.edu',
#   'field': nan,
#   'folders_above_avg': {1386128824.0: 0},
#   'frac_multitasking_days_over_active_days': 0.0,
#   'frac_multitasking_days_overall': 0.0,
#   'geoloc': '(39.0549176, -94.6090437) 66160',
#   'gini_act_across_folders': 0.0,
#   'gini_num_days_present_over_folders': 0.0,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': nan,
#   'number_folders': 1,
#   'overall_num_active_days': 3,
#   'user_id': 271583265.0,
#   'user_tot_act': 5.0,
#   'user_tot_num_adds': 3.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 2.0,
#   'user_univ_ranking': nan,
#   'world_ranking': nan},
#  17827874.0: {'Country': 'United States',
#   'University_name': 'lick observatory',
#   'act_period': 209,
#   'burstiness': 0.71959731382823156,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 1.2884169849349072,
#   'eff_num_folders_by_days_present': 3.1370259650115111,
#   'email_domain': 'ucolick.org',
#   'field': nan,
#   'folders_above_avg': {1185414796.0: 0,
#    1257078468.0: 1,
#    1265414499.0: 0,
#    1341326913.0: 0},
#   'frac_multitasking_days_over_active_days': 0.06666666666666667,
#   'frac_multitasking_days_overall': 0.004784688995215311,
#   'geoloc': '(37.341413, -121.6429102) 95140',
#   'gini_act_across_folders': 0.7119047619047619,
#   'gini_num_days_present_over_folders': 0.375,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': nan,
#   'number_folders': 4,
#   'overall_num_active_days': 15,
#   'user_id': 17827874.0,
#   'user_tot_act': 315.0,
#   'user_tot_num_adds': 291.0,
#   'user_tot_num_deletes': 6.0,
#   'user_tot_num_edits': 18.0,
#   'user_univ_ranking': nan,
#   'world_ranking': nan},
#  641730595.0: {'Country': 'United States',
#   'University_name': 'university of texas southwestern medical center',
#   'act_period': 0,
#   'avg_interevent_time': nan,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'utsouthwestern.edu',
#   'field': nan,
#   'folders_above_avg': {1395363375.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(32.812123, -96.8400459) 75390',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 46.0,
#   'number_folders': 1,
#   'overall_num_active_days': 0,
#   'user_id': 641730595.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 75.0,
#   'world_ranking': 75.0},
#  613419045.0: {'Country': 'United States',
#   'University_name': 'university of virginia',
#   'act_period': 0,
#   'avg_interevent_time': nan,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'virginia.edu',
#   'field': nan,
#   'folders_above_avg': {1337829185.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(38.0335529, -78.5079772) 22903',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 26.0,
#   'number_folders': 1,
#   'overall_num_active_days': 0,
#   'user_id': 613419045.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 41.0,
#   'world_ranking': 41.0},
#  466616358.0: {'Country': 'United States',
#   'University_name': 'stanford university',
#   'act_period': 232,
#   'burstiness': 0.45781256977087448,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 3.2026967520724399,
#   'eff_num_folders_by_days_present': 3.2890836391458369,
#   'email_domain': 'stanford.edu',
#   'field': nan,
#   'folders_above_avg': {1174583688.0: 0,
#    1190237991.0: 1,
#    1233755539.0: 0,
#    1345186292.0: 0},
#   'frac_multitasking_days_over_active_days': 0.1,
#   'frac_multitasking_days_overall': 0.008620689655172414,
#   'geoloc': '(37.4274745, -122.169719) 94305',
#   'gini_act_across_folders': 0.34517045454545453,
#   'gini_num_days_present_over_folders': 0.3409090909090909,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 2.0,
#   'number_folders': 4,
#   'overall_num_active_days': 20,
#   'user_id': 466616358.0,
#   'user_tot_act': 352.0,
#   'user_tot_num_adds': 288.0,
#   'user_tot_num_deletes': 30.0,
#   'user_tot_num_edits': 34.0,
#   'user_univ_ranking': 2.0,
#   'world_ranking': 2.0},
#  12582951.0: {'Country': 'Germany',
#   'University_name': 'university of cologne',
#   'act_period': 0,
#   'avg_interevent_time': nan,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'uni-koeln.de',
#   'field': nan,
#   'folders_above_avg': {1294389883.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(50.9281625, 6.9288192) 50923',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 12.0,
#   'number_folders': 1,
#   'overall_num_active_days': 0,
#   'user_id': 12582951.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 197.0,
#   'world_ranking': 197.0},
#  404752426.0: {'Country': 'United States',
#   'University_name': 'university of wisconsin-madison',
#   'act_period': 0,
#   'avg_interevent_time': nan,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'wisc.edu',
#   'field': nan,
#   'folders_above_avg': {1421513007.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(43.076592, -89.4124875) 53706',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 18.0,
#   'number_folders': 1,
#   'overall_num_active_days': 0,
#   'user_id': 404752426.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 25.0,
#   'world_ranking': 25.0},
#  442499115.0: {'Country': 'United States',
#   'University_name': 'university of cincinnati',
#   'act_period': 0,
#   'avg_interevent_time': nan,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'uc.edu',
#   'field': nan,
#   'folders_above_avg': {137418974.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(39.1329219, -84.51495039999999) 45220',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 72.0,
#   'number_folders': 1,
#   'overall_num_active_days': 0,
#   'user_id': 442499115.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 157.0,
#   'world_ranking': 157.0},
#  578816044.0: {'Country': 'United States',
#   'University_name': 'johns hopkins university',
#   'act_period': 0,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 1.0,
#   'eff_num_folders_by_days_present': 1.0,
#   'email_domain': 'jhmi.edu',
#   'field': nan,
#   'folders_above_avg': {251320577.0: 0, 278802710.0: 0, 1035795694.0: 1},
#   'frac_multitasking_days_over_active_days': 0.0,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(39.3299013, -76.6205177) 21218',
#   'gini_act_across_folders': 0.6666666666666666,
#   'gini_num_days_present_over_folders': 0.6666666666666666,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 13.0,
#   'number_folders': 3,
#   'overall_num_active_days': 1,
#   'user_id': 578816044.0,
#   'user_tot_act': 53.0,
#   'user_tot_num_adds': 53.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 16.0,
#   'world_ranking': 16.0},
#  46139664.0: {'Country': 'South Africa',
#   'University_name': 'university of cape town',
#   'act_period': 0,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 1.0,
#   'eff_num_folders_by_days_present': 1.0,
#   'email_domain': 'uct.ac.za',
#   'field': nan,
#   'folders_above_avg': {159454540.0: 0,
#    228480611.0: 1,
#    473169198.0: 0,
#    948752689.0: 0,
#    1169104077.0: 0},
#   'frac_multitasking_days_over_active_days': 0.0,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(-33.957652, 18.4611991) 7701',
#   'gini_act_across_folders': 0.8,
#   'gini_num_days_present_over_folders': 0.8,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 2.0,
#   'number_folders': 5,
#   'overall_num_active_days': 1,
#   'user_id': 46139664.0,
#   'user_tot_act': 15.0,
#   'user_tot_num_adds': 15.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 248.0,
#   'world_ranking': 248.0},
#  180355120.0: {'Country': 'United States',
#   'University_name': 'university of iowa',
#   'act_period': 0,
#   'avg_interevent_time': nan,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'uiowa.edu',
#   'field': nan,
#   'folders_above_avg': {288201065.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(41.6626963, -91.5548998) 52242',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 67.0,
#   'number_folders': 1,
#   'overall_num_active_days': 0,
#   'user_id': 180355120.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 141.0,
#   'world_ranking': 141.0},
#  63963185.0: {'Country': 'United States',
#   'University_name': 'ohio state university',
#   'act_period': 5,
#   'burstiness': 0.38379708924283062,
#   'career_stage': 'sr',
#   'category_total_cit': 4.0,
#   'category_total_last_auth': 4.0,
#   'category_total_publ': 5.0,
#   'eff_num_folders': 1.0253794343529699,
#   'eff_num_folders_by_days_present': 1.7547653506033232,
#   'email_domain': 'osu.edu',
#   'field': 'humanities',
#   'folders_above_avg': {85917864.0: 1,
#    105591836.0: 0,
#    596789330.0: 0,
#    721278576.0: 0,
#    885759787.0: 0,
#    1261079460.0: 0,
#    1324691100.0: 0,
#    1407708092.0: 0},
#   'frac_multitasking_days_over_active_days': 0.0,
#   'frac_multitasking_days_overall': 0.0,
#   'geoloc': '(40.0141905, -83.03091429999999) 43210',
#   'gini_act_across_folders': 0.8740458015267175,
#   'gini_num_days_present_over_folders': 0.8125,
#   'group_num_citations': '229.0-1183.0',
#   'group_num_papers_last': '18.0-1216.0',
#   'group_total_publ': '56.0-1350.0',
#   'national_ranking': 32.0,
#   'number_folders': 8,
#   'overall_num_active_days': 4,
#   'user_id': 63963185.0,
#   'user_tot_act': 262.0,
#   'user_tot_num_adds': 38.0,
#   'user_tot_num_deletes': 223.0,
#   'user_tot_num_edits': 1.0,
#   'user_univ_ranking': 49.0,
#   'world_ranking': 49.0},
#  100663346.0: {'Country': 'United States',
#   'University_name': 'university of iowa',
#   'act_period': 0,
#   'burstiness': 1.1233795322950433,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 1.1144487307066862,
#   'eff_num_folders_by_days_present': 1.6243278367756078,
#   'email_domain': 'uiowa.edu',
#   'field': nan,
#   'folders_above_avg': {156875113.0: 0,
#    254694922.0: 0,
#    840312909.0: 0,
#    1077465414.0: 0,
#    1124323519.0: 1},
#   'frac_multitasking_days_over_active_days': 0.0,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(41.6626963, -91.5548998) 52242',
#   'gini_act_across_folders': 0.7884615384615384,
#   'gini_num_days_present_over_folders': 0.72,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 67.0,
#   'number_folders': 5,
#   'overall_num_active_days': 15,
#   'user_id': 100663346.0,
#   'user_tot_act': 104.0,
#   'user_tot_num_adds': 59.0,
#   'user_tot_num_deletes': 23.0,
#   'user_tot_num_edits': 22.0,
#   'user_univ_ranking': 141.0,
#   'world_ranking': 141.0},
#  529532979.0: {'Country': 'United States',
#   'University_name': 'harvard university',
#   'act_period': 0,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 1.0,
#   'eff_num_folders_by_days_present': 1.0,
#   'email_domain': 'mgh.harvard.edu',
#   'field': nan,
#   'folders_above_avg': {769614292.0: 0,
#    853097004.0: 0,
#    1154850941.0: 0,
#    1417658842.0: 1},
#   'frac_multitasking_days_over_active_days': 0.0,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(42.3770029, -71.11666009999999) 02138',
#   'gini_act_across_folders': 0.75,
#   'gini_num_days_present_over_folders': 0.75,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 1.0,
#   'number_folders': 4,
#   'overall_num_active_days': 1,
#   'user_id': 529532979.0,
#   'user_tot_act': 1.0,
#   'user_tot_num_adds': 1.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 1.0,
#   'world_ranking': 1.0},
#  225445940.0: {'Country': 'United States',
#   'University_name': 'emory university',
#   'act_period': 0,
#   'avg_interevent_time': nan,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'emory.edu',
#   'field': nan,
#   'folders_above_avg': {442158854.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(33.7925195, -84.32399889999999) 30322',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 51.0,
#   'number_folders': 1,
#   'overall_num_active_days': 0,
#   'user_id': 225445940.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 84.0,
#   'world_ranking': 84.0},
#  3145783.0: {'Country': 'United States',
#   'University_name': 'temple university',
#   'act_period': 0,
#   'burstiness': 0.44142174651564969,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 1.1437957673507562,
#   'eff_num_folders_by_days_present': 1.2992205177568863,
#   'email_domain': 'temple.edu',
#   'field': nan,
#   'folders_above_avg': {264891181.0: 0,
#    490400305.0: 0,
#    544374571.0: 1,
#    737131191.0: 0},
#   'frac_multitasking_days_over_active_days': 0.0,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(39.9811932, -75.15535059999999) 19122',
#   'gini_act_across_folders': 0.7350560398505604,
#   'gini_num_days_present_over_folders': 0.7134146341463414,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 133.0,
#   'number_folders': 4,
#   'overall_num_active_days': 41,
#   'user_id': 3145783.0,
#   'user_tot_act': 803.0,
#   'user_tot_num_adds': 230.0,
#   'user_tot_num_deletes': 181.0,
#   'user_tot_num_edits': 392.0,
#   'user_univ_ranking': 381.0,
#   'world_ranking': 381.0},
#  310378552.0: {'Country': 'United States',
#   'University_name': 'brown university',
#   'act_period': 0,
#   'avg_interevent_time': nan,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'brown.edu',
#   'field': nan,
#   'folders_above_avg': {1136590896.0: 0, 1428381364.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(41.8267718, -71.4025482) 02912',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 50.0,
#   'number_folders': 2,
#   'overall_num_active_days': 0,
#   'user_id': 310378552.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 83.0,
#   'world_ranking': 83.0},
#  10485817.0: {'Country': 'United States',
#   'University_name': 'michigan state university',
#   'act_period': 0,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'msu.edu',
#   'field': nan,
#   'folders_above_avg': {7241419.0: 0,
#    19080062.0: 0,
#    20612165.0: 0,
#    637910871.0: 0,
#    1087236857.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(42.701848, -84.4821719) 48824',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 60.0,
#   'number_folders': 5,
#   'overall_num_active_days': 0,
#   'user_id': 10485817.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 118.0,
#   'world_ranking': 118.0},
#  67110970.0: {'Country': 'United States',
#   'University_name': 'university of chicago',
#   'act_period': 0,
#   'burstiness': nan,
#   'career_stage': 'sr',
#   'category_total_cit': 4.0,
#   'category_total_last_auth': 4.0,
#   'category_total_publ': 5.0,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'uchicago.edu',
#   'field': 'humanities',
#   'folders_above_avg': {71879470.0: 0,
#    187380324.0: 0,
#    427574480.0: 0,
#    1388787443.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(41.7886079, -87.5987133) 60637',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': '229.0-1183.0',
#   'group_num_papers_last': '18.0-1216.0',
#   'group_total_publ': '56.0-1350.0',
#   'national_ranking': 6.0,
#   'number_folders': 4,
#   'overall_num_active_days': 0,
#   'user_id': 67110970.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 8.0,
#   'world_ranking': 8.0},
#  377487419.0: {'Country': 'United States',
#   'University_name': 'university of massachusetts amherst',
#   'act_period': 264,
#   'burstiness': 0.038462399864865493,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 1.0,
#   'eff_num_folders_by_days_present': 1.0,
#   'email_domain': 'soc.umass.edu',
#   'field': nan,
#   'folders_above_avg': {259451791.0: 0},
#   'frac_multitasking_days_over_active_days': 0.0,
#   'frac_multitasking_days_overall': 0.0,
#   'geoloc': '(42.3911569, -72.5267121) 01003',
#   'gini_act_across_folders': 0.0,
#   'gini_num_days_present_over_folders': 0.0,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 91.0,
#   'number_folders': 1,
#   'overall_num_active_days': 9,
#   'user_id': 377487419.0,
#   'user_tot_act': 111.0,
#   'user_tot_num_adds': 105.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 6.0,
#   'user_univ_ranking': 219.0,
#   'world_ranking': 219.0},
#  378538044.0: {'Country': 'United States',
#   'University_name': 'purdue university',
#   'act_period': 0,
#   'avg_interevent_time': nan,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'purdue.edu',
#   'field': nan,
#   'folders_above_avg': {806516282.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(40.4237054, -86.92119459999999) 47907',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 74.0,
#   'number_folders': 1,
#   'overall_num_active_days': 0,
#   'user_id': 378538044.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 164.0,
#   'world_ranking': 164.0},
#  156237886.0: {'Country': 'United States',
#   'University_name': 'university of georgia',
#   'act_period': 0,
#   'burstiness': 0.57046260652391234,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 1.0,
#   'eff_num_folders_by_days_present': 1.0,
#   'email_domain': 'uga.edu',
#   'field': nan,
#   'folders_above_avg': {508520697.0: 0, 897738062.0: 1},
#   'frac_multitasking_days_over_active_days': 0.0,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(33.9480053, -83.3773221) 30602',
#   'gini_act_across_folders': 0.5,
#   'gini_num_days_present_over_folders': 0.5,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 86.0,
#   'number_folders': 2,
#   'overall_num_active_days': 30,
#   'user_id': 156237886.0,
#   'user_tot_act': 4575.0,
#   'user_tot_num_adds': 2313.0,
#   'user_tot_num_deletes': 2133.0,
#   'user_tot_num_edits': 129.0,
#   'user_univ_ranking': 198.0,
#   'world_ranking': 198.0},
#  103811135.0: {'Country': 'South Korea',
#   'University_name': 'hankuk university of foreign studies',
#   'act_period': 0,
#   'avg_interevent_time': nan,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'hufs.ac.kr',
#   'field': nan,
#   'folders_above_avg': {168290420.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(37.597319, 127.057843) 130-081',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': nan,
#   'number_folders': 1,
#   'overall_num_active_days': 0,
#   'user_id': 103811135.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': nan,
#   'world_ranking': nan},
#  208666688.0: {'Country': 'United States',
#   'University_name': 'north carolina state university',
#   'act_period': 0,
#   'avg_interevent_time': nan,
#   'burstiness': nan,
#   'career_stage': 'jr',
#   'category_total_cit': 2.0,
#   'category_total_last_auth': 1.0,
#   'category_total_publ': 1.0,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'ncsu.edu',
#   'field': 'business econ finances government',
#   'folders_above_avg': {330100266.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(35.7846633, -78.6820946) 27695',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': '1.0-30.0',
#   'group_num_papers_last': '0.0-1.0',
#   'group_total_publ': '1.0-2.0',
#   'national_ranking': 93.0,
#   'number_folders': 1,
#   'overall_num_active_days': 0,
#   'user_id': 208666688.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 232.0,
#   'world_ranking': 232.0},
#  236417376.0: {'Country': 'United States',
#   'University_name': 'drexel university',
#   'act_period': 0,
#   'burstiness': nan,
#   'career_stage': 'jr',
#   'category_total_cit': 2.0,
#   'category_total_last_auth': 1.0,
#   'category_total_publ': 2.0,
#   'eff_num_folders': 1.0,
#   'eff_num_folders_by_days_present': 1.0,
#   'email_domain': 'drexel.edu',
#   'field': 'other',
#   'folders_above_avg': {431236835.0: 0,
#    494700060.0: 0,
#    557775300.0: 0,
#    589107960.0: 0,
#    711271296.0: 0,
#    891418119.0: 0,
#    994149458.0: 1},
#   'frac_multitasking_days_over_active_days': 0.0,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(39.9566127, -75.18994409999999) 19104',
#   'gini_act_across_folders': 0.8571428571428571,
#   'gini_num_days_present_over_folders': 0.8571428571428571,
#   'group_num_citations': '1.0-30.0',
#   'group_num_papers_last': '0.0-1.0',
#   'group_total_publ': '2.0-8.0',
#   'national_ranking': 99.0,
#   'number_folders': 7,
#   'overall_num_active_days': 1,
#   'user_id': 236417376.0,
#   'user_tot_act': 195.0,
#   'user_tot_num_adds': 195.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 258.0,
#   'world_ranking': 258.0},
#  662702146.0: {'Country': 'United States',
#   'University_name': 'university of colorado denve',
#   'act_period': 0,
#   'avg_interevent_time': nan,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'ucdenver.edu',
#   'field': nan,
#   'folders_above_avg': {1441780531.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(39.7463895, -105.0023325) 80204',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': nan,
#   'number_folders': 1,
#   'overall_num_active_days': 0,
#   'user_id': 662702146.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': nan,
#   'world_ranking': nan},
#  332398659.0: {'Country': 'United States',
#   'University_name': 'university of massachusetts boston',
#   'act_period': 0,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'umb.edu',
#   'field': nan,
#   'folders_above_avg': {692221344.0: 0, 1327894403.0: 0, 1451790675.0: 0},
# ...
#   'email_domain': 'gse.upenn.edu',
#   'field': nan,
#   'folders_above_avg': {11669255.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(39.9522188, -75.1932137) 19104',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 11.0,
#   'number_folders': 1,
#   'overall_num_active_days': 0,
#   'user_id': 106326009.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 14.0,
#   'world_ranking': 14.0},
#  72353752.0: {'Country': 'Palestinian Territory',
#   'University_name': 'birzeit university',
#   'act_period': 0,
#   'avg_interevent_time': nan,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'birzeit.edu',
#   'field': nan,
#   'folders_above_avg': {644821957.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(31.9591925, 35.1820071) ',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': nan,
#   'number_folders': 1,
#   'overall_num_active_days': 0,
#   'user_id': 72353752.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': nan,
#   'world_ranking': nan},
#  122684891.0: {'Country': 'United States',
#   'University_name': 'university of wisconsin-madison',
#   'act_period': 0,
#   'avg_interevent_time': nan,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'bus.wisc.edu',
#   'field': nan,
#   'folders_above_avg': {832250689.0: 0, 859905056.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(43.076592, -89.4124875) 53706',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 18.0,
#   'number_folders': 2,
#   'overall_num_active_days': 0,
#   'user_id': 122684891.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 25.0,
#   'world_ranking': 25.0},
#  52430815.0: {'Country': 'United States',
#   'University_name': 'university of wisconsin-madison',
#   'act_period': 0,
#   'avg_interevent_time': nan,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'wisc.edu',
#   'field': nan,
#   'folders_above_avg': {541593293.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(43.076592, -89.4124875) 53706',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 18.0,
#   'number_folders': 1,
#   'overall_num_active_days': 0,
#   'user_id': 52430815.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 25.0,
#   'world_ranking': 25.0},
#  332400608.0: {'Country': 'United States',
#   'University_name': 'university of southern california',
#   'act_period': 0,
#   'avg_interevent_time': nan,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'usc.edu',
#   'field': nan,
#   'folders_above_avg': {732037504.0: 0, 835940018.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(34.0223519, -118.285117) 90007',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 34.0,
#   'number_folders': 2,
#   'overall_num_active_days': 0,
#   'user_id': 332400608.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 51.0,
#   'world_ranking': 51.0},
#  523239760.0: {'Country': 'United States',
#   'University_name': 'northeastern university',
#   'act_period': 1,
#   'avg_interevent_time': nan,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 1.0,
#   'eff_num_folders_by_days_present': 1.0,
#   'email_domain': 'husky.neu.edu',
#   'field': nan,
#   'folders_above_avg': {1368237535.0: 0},
#   'frac_multitasking_days_over_active_days': 0.0,
#   'frac_multitasking_days_overall': 0.0,
#   'geoloc': '(42.3398067, -71.0891717) 02115',
#   'gini_act_across_folders': 0.0,
#   'gini_num_days_present_over_folders': 0.0,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 108.0,
#   'number_folders': 1,
#   'overall_num_active_days': 1,
#   'user_id': 523239760.0,
#   'user_tot_act': 1.0,
#   'user_tot_num_adds': 1.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 275.0,
#   'world_ranking': 275.0},
#  69208037.0: {'Country': 'United States',
#   'University_name': 'texas a&m university',
#   'act_period': 0,
#   'burstiness': 1.0104548242721814,
#   'career_stage': 'sr',
#   'category_total_cit': 4.0,
#   'category_total_last_auth': 4.0,
#   'category_total_publ': 4.0,
#   'eff_num_folders': 1.7558419153157263,
#   'eff_num_folders_by_days_present': 3.8829596818032575,
#   'email_domain': 'tamu.edu',
#   'field': 'science',
#   'folders_above_avg': {536669949.0: 0,
#    832040747.0: 0,
#    835878636.0: 0,
#    895299268.0: 0,
#    940738134.0: 0,
#    992932699.0: 0,
#    993075565.0: 0,
#    1017740624.0: 0,
#    1020727668.0: 0,
#    1023271118.0: 1,
#    1069033290.0: 0,
#    1108063265.0: 0,
#    1142750244.0: 0,
#    1172715693.0: 0,
#    1173892785.0: 0,
#    1210711697.0: 0,
#    1220148368.0: 0,
#    1230226956.0: 0,
#    1257411561.0: 0,
#    1294118397.0: 0,
#    1294118673.0: 0,
#    1297400900.0: 0,
#    1315145602.0: 0,
#    1315146307.0: 0,
#    1339856923.0: 0,
#    1348997591.0: 0,
#    1363734602.0: 0,
#    1368904965.0: 0,
#    1368905160.0: 0,
#    1384538791.0: 0,
#    1395476632.0: 1,
#    1408106587.0: 0,
#    1424210858.0: 0},
#   'frac_multitasking_days_over_active_days': 0.08695652173913043,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(31.9685988, -99.9018131) ',
#   'gini_act_across_folders': 0.9547417419101565,
#   'gini_num_days_present_over_folders': 0.8981818181818182,
#   'group_num_citations': '229.0-1183.0',
#   'group_num_papers_last': '18.0-1216.0',
#   'group_total_publ': '22.0-56.0',
#   'national_ranking': 56.0,
#   'number_folders': 33,
#   'overall_num_active_days': 46,
#   'user_id': 69208037.0,
#   'user_tot_act': 1621.0,
#   'user_tot_num_adds': 757.0,
#   'user_tot_num_deletes': 432.0,
#   'user_tot_num_edits': 432.0,
#   'user_univ_ranking': 102.0,
#   'world_ranking': 102.0},
#  99616742.0: {'Country': 'United States',
#   'University_name': 'university of minnesota ',
#   'act_period': 470,
#   'burstiness': 0.48369167735373497,
#   'career_stage': 'sr',
#   'category_total_cit': 3.0,
#   'category_total_last_auth': 2.0,
#   'category_total_publ': 3.0,
#   'eff_num_folders': 1.0109676914127512,
#   'eff_num_folders_by_days_present': 1.2289892094880017,
#   'email_domain': 'umn.edu',
#   'field': 'humanities',
#   'folders_above_avg': {796764730.0: 1,
#    1025119950.0: 0,
#    1282720329.0: 0,
#    1315425439.0: 0},
#   'frac_multitasking_days_over_active_days': 0.0,
#   'frac_multitasking_days_overall': 0.0,
#   'geoloc': '(44.97399, -93.2277285) 55455',
#   'gini_act_across_folders': 0.7492764109985528,
#   'gini_num_days_present_over_folders': 0.7236842105263158,
#   'group_num_citations': '30.0-229.0',
#   'group_num_papers_last': '1.0-5.0',
#   'group_total_publ': '8.0-22.0',
#   'national_ranking': nan,
#   'number_folders': 4,
#   'overall_num_active_days': 19,
#   'user_id': 99616742.0,
#   'user_tot_act': 691.0,
#   'user_tot_num_adds': 121.0,
#   'user_tot_num_deletes': 180.0,
#   'user_tot_num_edits': 390.0,
#   'user_univ_ranking': nan,
#   'world_ranking': nan},
#  597690345.0: {'Country': 'United States',
#   'University_name': 'colorado state university',
#   'act_period': 1,
#   'avg_interevent_time': nan,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 1.0,
#   'eff_num_folders_by_days_present': 1.0,
#   'email_domain': 'rams.colostate.edu',
#   'field': nan,
#   'folders_above_avg': {1293532524.0: 0},
#   'frac_multitasking_days_over_active_days': 0.0,
#   'frac_multitasking_days_overall': 0.0,
#   'geoloc': '(40.573436, -105.0865473) 80523',
#   'gini_act_across_folders': 0.0,
#   'gini_num_days_present_over_folders': 0.0,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 104.0,
#   'number_folders': 1,
#   'overall_num_active_days': 1,
#   'user_id': 597690345.0,
#   'user_tot_act': 1.0,
#   'user_tot_num_adds': 1.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 271.0,
#   'world_ranking': 271.0},
#  380635117.0: {'Country': 'United States',
#   'University_name': 'texas a&m university',
#   'act_period': 0,
#   'avg_interevent_time': nan,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'tamu.edu',
#   'field': 'science',
#   'folders_above_avg': {1160720261.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(31.9685988, -99.9018131) ',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 56.0,
#   'number_folders': 1,
#   'overall_num_active_days': 0,
#   'user_id': 380635117.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 102.0,
#   'world_ranking': 102.0},
#  77596654.0: {'Country': 'United States',
#   'University_name': 'university of hawaii',
#   'act_period': 0,
#   'burstiness': 0.33333333333333331,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 1.0347413496718127,
#   'eff_num_folders_by_days_present': 1.8898815748423099,
#   'email_domain': 'ctahr.hawaii.edu',
#   'field': nan,
#   'folders_above_avg': {814035822.0: 0,
#    1074543987.0: 0,
#    1251979305.0: 0,
#    1387168117.0: 0,
#    1465875392.0: 1},
#   'frac_multitasking_days_over_active_days': 0.0,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(21.296939, -157.8171118) 96822',
#   'gini_act_across_folders': 0.7977961432506887,
#   'gini_num_days_present_over_folders': 0.6666666666666666,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 156.0,
#   'number_folders': 5,
#   'overall_num_active_days': 3,
#   'user_id': 77596654.0,
#   'user_tot_act': 1815.0,
#   'user_tot_num_adds': 1815.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 488.0,
#   'world_ranking': 488.0},
#  487589874.0: {'Country': 'Australia',
#   'University_name': 'university of melbourne',
#   'act_period': 116,
#   'burstiness': 0.017746169702850926,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 1.0,
#   'eff_num_folders_by_days_present': 1.0,
#   'email_domain': 'unimelb.edu.au',
#   'field': nan,
#   'folders_above_avg': {1061644247.0: 0},
#   'frac_multitasking_days_over_active_days': 0.0,
#   'frac_multitasking_days_overall': 0.0,
#   'geoloc': '(-37.7963689, 144.9611738) 3010',
#   'gini_act_across_folders': 0.0,
#   'gini_num_days_present_over_folders': 0.0,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 2.0,
#   'number_folders': 1,
#   'overall_num_active_days': 4,
#   'user_id': 487589874.0,
#   'user_tot_act': 14.0,
#   'user_tot_num_adds': 10.0,
#   'user_tot_num_deletes': 3.0,
#   'user_tot_num_edits': 1.0,
#   'user_univ_ranking': 93.0,
#   'world_ranking': 93.0},
#  606078965.0: {'Country': 'United States',
#   'University_name': 'university of illinois',
#   'act_period': 0,
#   'burstiness': 0.12308791638837076,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 1.0,
#   'eff_num_folders_by_days_present': 1.0,
#   'email_domain': 'illinois.edu',
#   'field': nan,
#   'folders_above_avg': {835047312.0: 0, 1313579271.0: 1},
#   'frac_multitasking_days_over_active_days': 0.0,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(40.1019523, -88.2271615) ',
#   'gini_act_across_folders': 0.5,
#   'gini_num_days_present_over_folders': 0.5,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': nan,
#   'number_folders': 2,
#   'overall_num_active_days': 10,
#   'user_id': 606078965.0,
#   'user_tot_act': 125.0,
#   'user_tot_num_adds': 59.0,
#   'user_tot_num_deletes': 21.0,
#   'user_tot_num_edits': 45.0,
#   'user_univ_ranking': nan,
#   'world_ranking': nan},
#  51228665.0: {'Country': 'Slovenia',
#   'University_name': 'university of ljubljana',
#   'act_period': 0,
#   'avg_interevent_time': nan,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'fri.uni-lj.si',
#   'field': nan,
#   'folders_above_avg': {528891620.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(46.0491938, 14.5041552) 1000',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 1.0,
#   'number_folders': 1,
#   'overall_num_active_days': 0,
#   'user_id': 51228665.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 504.0,
#   'world_ranking': 504.0},
#  559941630.0: {'Country': 'United States',
#   'University_name': 'university of south florida',
#   'act_period': 0,
#   'avg_interevent_time': nan,
#   'burstiness': nan,
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 0,
#   'eff_num_folders_by_days_present': 0,
#   'email_domain': 'mail.usf.edu',
#   'field': nan,
#   'folders_above_avg': {1204407054.0: 0, 1204407484.0: 0},
#   'frac_multitasking_days_over_active_days': nan,
#   'frac_multitasking_days_overall': nan,
#   'geoloc': '(28.0587031, -82.41385389999999) 33620',
#   'gini_act_across_folders': nan,
#   'gini_num_days_present_over_folders': nan,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 83.0,
#   'number_folders': 2,
#   'overall_num_active_days': 0,
#   'user_id': 559941630.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 190.0,
#   'world_ranking': 190.0},
#  ...}

# %%
df_user_basic_attr[df_user_basic_attr["user_id"]==629145600]
#df_all_act.date.dropna().unique()
df_user_basic_attr
# Out:
#         Unnamed: 0      user_id            email_domain  \
# 0                0      76604.0                 unc.edu
# 1                1     130678.0            columbia.edu
# 2                2     178708.0             cornell.edu
# 3                3    1148983.0              cs.cmu.edu
# 4                4     278109.0              cs.cmu.edu
# 5                5     258758.0             iastate.edu
# 6                6     256616.0        mail.xjtu.edu.cn
# 7                7     272328.0                uark.edu
# 8                8     284032.0         walton.uark.edu
# 9                9     287646.0                ncsu.edu
# 10              10     321561.0             hcs.ufl.edu
# 11              11    7396226.0             ece.ufl.edu
# 12              12     684280.0                jhmi.edu
# 13              13    1017441.0                kumc.edu
# 14              14     383335.0             cornell.edu
# 15              15     382650.0             cornell.edu
# 16              16     392592.0              bham.ac.uk
# 17              17     390695.0             ucdavis.edu
# 18              18    2990310.0              tulane.edu
# 19              19     382955.0                duke.edu
# 20              20     405461.0           econ.ucla.edu
# 21              21     407729.0                 uci.edu
# 22              22   17245311.0            ssc.wisc.edu
# 23              23     164005.0           math.wisc.edu
# 24              24     507813.0               wustl.edu
# 25              25     528183.0               umich.edu
# 26              26     612255.0            virginia.edu
# 27              27     539789.0       english.umass.edu
# 28              28     227037.0       history.umass.edu
# 29              29     584184.0       history.umass.edu
# ...            ...          ...                     ...
# 438270      438270  547451537.0        st-andrews.ac.uk
# 438271      438271   24259861.0           lens.unifi.it
# 438272      438272   62702014.0                 upct.es
# 438273      438273   18392052.0                   uv.es
# 438274      438274  265403388.0                   um.es
# 438275      438275    8650032.0                  uam.es
# 438276      438276  526286256.0                hw.ac.uk
# 438277      438277  645866575.0                  ugr.es
# 438278      438278     595672.0             univ-amu.fr
# 438279      438279  100067006.0  physik.uni-freiburg.de
# 438280      438280  588126019.0        st-andrews.ac.uk
# 438281      438281   23442058.0                  ugr.es
# 438282      438282    7231365.0         phys.huji.ac.il
# 438283      438283  502619146.0              bath.ac.uk
# 438284      438284  671640109.0             fysik.su.se
# 438285      438285  189953791.0                  ehu.es
# 438286      438286  464209382.0                 upmc.fr
# 438287      438287  113538696.0               umich.edu
# 438288      438288  670003816.0                 ufl.edu
# 438289      438289  522512724.0                 ufl.edu
# 438290      438290  586494770.0               brown.edu
# 438291      438291  676128683.0          georgetown.edu
# 438292      438292  245709659.0                pitt.edu
# 438293      438293  672070700.0                ndsu.edu
# 438294      438294  671507016.0           uillinois.edu
# 438295      438295  152079229.0            stanford.edu
# 438296      438296  397152086.0                 ufl.edu
# 438297      438297  673760400.0        northwestern.edu
# 438298      438298  671519417.0       email.arizona.edu
# 438299      438299  517370404.0                 asu.edu
#
#                                           field group_total_publ  \
# 0                                    humanities              NaN
# 1                                       science          1.0-2.0
# 2             business econ finances government              NaN
# 3                                    humanities              NaN
# 4                                    humanities              NaN
# 5                                       science        22.0-56.0
# 6                                           NaN              NaN
# 7             business econ finances government         8.0-22.0
# 8                                           NaN              NaN
# 9                                       science              NaN
# 10                                          NaN              NaN
# 11                                      science              NaN
# 12      medicine dentistry nursing pharmacology          1.0-2.0
# 13                                          NaN              NaN
# 14                                      science      56.0-1350.0
# 15                                          NaN              NaN
# 16                                          NaN              NaN
# 17                                   humanities          2.0-8.0
# 18                                          NaN              NaN
# 19                                          NaN              NaN
# 20            business econ finances government         8.0-22.0
# 21                                      science              NaN
# 22                                   humanities              NaN
# 23                                      science              NaN
# 24                                   humanities              NaN
# 25                                          NaN              NaN
# 26                                          NaN              NaN
# 27                                          NaN              NaN
# 28                                          NaN              NaN
# 29                                          NaN              NaN
# ...                                         ...              ...
# 438270                                      NaN              NaN
# 438271                                      NaN              NaN
# 438272                                      NaN              NaN
# 438273                                      NaN              NaN
# 438274                                      NaN              NaN
# 438275                                      NaN              NaN
# 438276                                      NaN              NaN
# 438277                                      NaN              NaN
# 438278                                      NaN              NaN
# 438279                                      NaN              NaN
# 438280                                      NaN              NaN
# 438281                                      NaN              NaN
# 438282                                      NaN              NaN
# 438283                                      NaN              NaN
# 438284                                      NaN              NaN
# 438285                                      NaN              NaN
# 438286                                      NaN              NaN
# 438287                                      NaN              NaN
# 438288                                      NaN              NaN
# 438289                                  science              NaN
# 438290                                      NaN              NaN
# 438291                                      NaN              NaN
# 438292                               humanities              NaN
# 438293                                      NaN              NaN
# 438294                                      NaN              NaN
# 438295                               humanities          2.0-8.0
# 438296                                      NaN              NaN
# 438297                                      NaN              NaN
# 438298                                      NaN              NaN
# 438299                                      NaN              NaN
#
#        group_num_papers_last group_num_citations  \
# 0                        NaN                 NaN
# 1                    0.0-1.0            1.0-30.0
# 2                        NaN                 NaN
# 3                        NaN                 NaN
# 4                        NaN                 NaN
# 5                   5.0-18.0     1183.0-146545.0
# 6                        NaN                 NaN
# 7                   5.0-18.0        229.0-1183.0
# 8                        NaN                 NaN
# 9                        NaN                 NaN
# 10                       NaN                 NaN
# 11                       NaN                 NaN
# 12                   0.0-1.0             0.0-1.0
# 13                       NaN                 NaN
# 14               18.0-1216.0     1183.0-146545.0
# 15                       NaN                 NaN
# 16                       NaN                 NaN
# 17                   0.0-1.0             0.0-1.0
# 18                       NaN                 NaN
# 19                       NaN                 NaN
# 20                   1.0-5.0        229.0-1183.0
# 21                       NaN                 NaN
# 22                       NaN                 NaN
# 23                       NaN                 NaN
# 24                       NaN                 NaN
# 25                       NaN                 NaN
# 26                       NaN                 NaN
# 27                       NaN                 NaN
# 28                       NaN                 NaN
# 29                       NaN                 NaN
# ...                      ...                 ...
# 438270                   NaN                 NaN
# 438271                   NaN                 NaN
# 438272                   NaN                 NaN
# 438273                   NaN                 NaN
# 438274                   NaN                 NaN
# 438275                   NaN                 NaN
# 438276                   NaN                 NaN
# 438277                   NaN                 NaN
# 438278                   NaN                 NaN
# 438279                   NaN                 NaN
# 438280                   NaN                 NaN
# 438281                   NaN                 NaN
# 438282                   NaN                 NaN
# 438283                   NaN                 NaN
# 438284                   NaN                 NaN
# 438285                   NaN                 NaN
# 438286                   NaN                 NaN
# 438287                   NaN                 NaN
# 438288                   NaN                 NaN
# 438289                   NaN                 NaN
# 438290                   NaN                 NaN
# 438291                   NaN                 NaN
# 438292                   NaN                 NaN
# 438293                   NaN                 NaN
# 438294                   NaN                 NaN
# 438295              5.0-18.0            1.0-30.0
# 438296                   NaN                 NaN
# 438297                   NaN                 NaN
# 438298                   NaN                 NaN
# 438299                   NaN                 NaN
#
#                                     University_name         Country  \
# 0       university of north carolina at chapel hill   United States
# 1                               columbia university   United States
# 2                                cornell university   United States
# 3                        carnegie mellon university   United States
# 4                        carnegie mellon university   United States
# 5                             iowa state university   United States
# 6                         xi'an jiaotong university           China
# 7                            university of arkansas   United States
# 8                            university of arkansas   United States
# 9                   north carolina state university   United States
# 10                            university of florida   United States
# 11                            university of florida   United States
# 12                         johns hopkins university   United States
# 13              university of kansas medical center   United States
# 14                               cornell university   United States
# 15                               cornell university   United States
# 16                         university of birmingham  United Kingdom
# 17                   university of california davis   United States
# 18                                tulane university   United States
# 19                                  duke university   United States
# 20             university of california los angeles   United States
# 21                  university of california irvine   United States
# 22                  university of wisconsin-madison   United States
# 23                  university of wisconsin-madison   United States
# 24                  washington university st. louis   United States
# 25                           university of michigan   United States
# 26                           university of virginia   United States
# 27              university of massachusetts amherst   United States
# 28              university of massachusetts amherst   United States
# 29              university of massachusetts amherst   United States
# ...                                             ...             ...
# 438270                     university of st andrews  United Kingdom
# 438271            universita degli studi di firenze           Italy
# 438272         universidad politecnica de cartagena           Spain
# 438273                      universitat de valencia           Spain
# 438274                        universidad de murcia           Spain
# 438275               universidad autonoma de madrid           Spain
# 438276             heriot-watt university edinburgh  United Kingdom
# 438277                        university of granada           Spain
# 438278                     aix marseille universite          France
# 438279                       university of freiburg         Germany
# 438280                     university of st andrews  United Kingdom
# 438281                        university of granada           Spain
# 438282               hebrew university of jerusalem          Israel
# 438283                           university of bath  United Kingdom
# 438284                         stockholm university          Sweden
# 438285             university of the basque country           Spain
# 438286            pierre and marie curie university          France
# 438287                       university of michigan   United States
# 438288                        university of florida   United States
# 438289                        university of florida   United States
# 438290                             brown university   United States
# 438291                        georgetown university   United States
# 438292                     university of pittsburgh   United States
# 438293                north dakota state university   United States
# 438294                       university of illinois   United States
# 438295                          stanford university   United States
# 438296                        university of florida   United States
# 438297                      northwestern university   United States
# 438298                        university of arizona   United States
# 438299                     arizona state university   United States
#
#         world_ranking  national_ranking career_stage  category_total_publ  \
# 0                40.0              25.0          NaN                  NaN
# 1                 6.0               4.0           jr                  1.0
# 2                10.0               8.0          NaN                  NaN
# 3                61.0              39.0          NaN                  NaN
# 4                61.0              39.0          NaN                  NaN
# 5               187.0              81.0           sr                  4.0
# 6               389.0              13.0          NaN                  NaN
# 7               550.0             168.0           sr                  3.0
# 8               550.0             168.0          NaN                  NaN
# 9               232.0              93.0          NaN                  NaN
# 10               60.0              38.0          NaN                  NaN
# 11               60.0              38.0          NaN                  NaN
# 12               16.0              13.0           jr                  1.0
# 13                NaN               NaN          NaN                  NaN
# 14               10.0               8.0           sr                  5.0
# 15               10.0               8.0          NaN                  NaN
# 16              152.0              12.0          NaN                  NaN
# 17               53.0              36.0           jr                  2.0
# 18              272.0             105.0          NaN                  NaN
# 19               28.0              20.0          NaN                  NaN
# 20               15.0              12.0           sr                  3.0
# 21               89.0              52.0          NaN                  NaN
# 22               25.0              18.0          NaN                  NaN
# 23               25.0              18.0          NaN                  NaN
# 24               52.0              35.0          NaN                  NaN
# 25               19.0              15.0          NaN                  NaN
# 26               41.0              26.0          NaN                  NaN
# 27              219.0              91.0          NaN                  NaN
# 28              219.0              91.0          NaN                  NaN
# 29              219.0              91.0          NaN                  NaN
# ...               ...               ...          ...                  ...
# 438270          309.0              28.0          NaN                  NaN
# 438271            NaN               NaN          NaN                  NaN
# 438272            NaN               NaN          NaN                  NaN
# 438273            NaN               NaN          NaN                  NaN
# 438274            NaN               NaN          NaN                  NaN
# 438275            NaN               NaN          NaN                  NaN
# 438276            NaN               NaN          NaN                  NaN
# 438277          431.0              11.0          NaN                  NaN
# 438278            NaN               NaN          NaN                  NaN
# 438279            NaN               NaN          NaN                  NaN
# 438280          309.0              28.0          NaN                  NaN
# 438281          431.0              11.0          NaN                  NaN
# 438282           23.0               1.0          NaN                  NaN
# 438283          405.0              34.0          NaN                  NaN
# 438284          168.0               5.0          NaN                  NaN
# 438285          485.0              15.0          NaN                  NaN
# 438286            NaN               NaN          NaN                  NaN
# 438287           19.0              15.0          NaN                  NaN
# 438288           60.0              38.0          NaN                  NaN
# 438289           60.0              38.0          NaN                  NaN
# 438290           83.0              50.0          NaN                  NaN
# 438291          113.0              59.0          NaN                  NaN
# 438292           46.0              29.0          NaN                  NaN
# 438293          792.0             211.0          NaN                  NaN
# 438294            NaN               NaN          NaN                  NaN
# 438295            2.0               2.0           jr                  2.0
# 438296           60.0              38.0          NaN                  NaN
# 438297           22.0              17.0          NaN                  NaN
# 438298           68.0              42.0          NaN                  NaN
# 438299           97.0              55.0          NaN                  NaN
#
#         category_total_last_auth  category_total_cit  \
# 0                            NaN                 NaN
# 1                            1.0                 2.0
# 2                            NaN                 NaN
# 3                            NaN                 NaN
# 4                            NaN                 NaN
# 5                            3.0                 5.0
# 6                            NaN                 NaN
# 7                            3.0                 4.0
# 8                            NaN                 NaN
# 9                            NaN                 NaN
# 10                           NaN                 NaN
# 11                           NaN                 NaN
# 12                           1.0                 1.0
# 13                           NaN                 NaN
# 14                           4.0                 5.0
# 15                           NaN                 NaN
# 16                           NaN                 NaN
# 17                           1.0                 1.0
# 18                           NaN                 NaN
# 19                           NaN                 NaN
# 20                           2.0                 4.0
# 21                           NaN                 NaN
# 22                           NaN                 NaN
# 23                           NaN                 NaN
# 24                           NaN                 NaN
# 25                           NaN                 NaN
# 26                           NaN                 NaN
# 27                           NaN                 NaN
# 28                           NaN                 NaN
# 29                           NaN                 NaN
# ...                          ...                 ...
# 438270                       NaN                 NaN
# 438271                       NaN                 NaN
# 438272                       NaN                 NaN
# 438273                       NaN                 NaN
# 438274                       NaN                 NaN
# 438275                       NaN                 NaN
# 438276                       NaN                 NaN
# 438277                       NaN                 NaN
# 438278                       NaN                 NaN
# 438279                       NaN                 NaN
# 438280                       NaN                 NaN
# 438281                       NaN                 NaN
# 438282                       NaN                 NaN
# 438283                       NaN                 NaN
# 438284                       NaN                 NaN
# 438285                       NaN                 NaN
# 438286                       NaN                 NaN
# 438287                       NaN                 NaN
# 438288                       NaN                 NaN
# 438289                       NaN                 NaN
# 438290                       NaN                 NaN
# 438291                       NaN                 NaN
# 438292                       NaN                 NaN
# 438293                       NaN                 NaN
# 438294                       NaN                 NaN
# 438295                       3.0                 2.0
# 438296                       NaN                 NaN
# 438297                       NaN                 NaN
# 438298                       NaN                 NaN
# 438299                       NaN                 NaN
#
#                                         geoloc
# 0                   (35.9049122, -79.0469134)
# 1              (40.8075355, -73.9625727) 10027
# 2              (42.4534492, -76.4735027) 14850
# 3       (40.4428081, -79.94301279999999) 15213
# 4       (40.4428081, -79.94301279999999) 15213
# 5              (42.0266187, -93.6464654) 50011
# 6                      (34.250575, 108.98371)
# 7       (36.0678324, -94.17365509999999) 72701
# 8       (36.0678324, -94.17365509999999) 72701
# 9              (35.7846633, -78.6820946) 27695
# 10             (29.6436325, -82.3549302) 32611
# 11             (29.6436325, -82.3549302) 32611
# 12             (39.3299013, -76.6205177) 21218
# 13             (39.0549176, -94.6090437) 66160
# 14             (42.4534492, -76.4735027) 14850
# 15             (42.4534492, -76.4735027) 14850
# 16            (52.4508168, -1.9305135) B15 2TT
# 17            (38.5382322, -121.7617125) 95616
# 18      (29.9403477, -90.12072789999999) 70118
# 19             (36.0014258, -78.9382286) 27708
# 20             (34.068921, -118.4451811) 90095
# 21            (33.6404952, -117.8442962) 92697
# 22              (43.076592, -89.4124875) 53706
# 23              (43.076592, -89.4124875) 53706
# 24      (38.6487895, -90.31079620000001) 63130
# 25             (42.2780436, -83.7382241) 48109
# 26             (38.0335529, -78.5079772) 22903
# 27             (42.3911569, -72.5267121) 01003
# 28             (42.3911569, -72.5267121) 01003
# 29             (42.3911569, -72.5267121) 01003
# ...                                        ...
# 438270       (56.3416934, -2.7927522) KY16 9AJ
# 438271           (43.7776426, 11.259765) 50121
# 438272           (37.604265, -0.9795883) 30202
# 438273          (39.4793254, -0.3593863) 46010
# 438274     (38.01875100000001, -1.16938) 30100
# 438275          (40.5466983, -3.6943619) 28049
# 438276       (55.9096602, -3.3203494) EH14 4AS
# 438277   (37.183853, -3.600766999999999) 18010
# 438278           (43.2922146, 5.3591422) 13284
# 438279   (47.9935441, 7.845949599999999) 79085
# 438280       (56.3416934, -2.7927522) KY16 9AJ
# 438281   (37.183853, -3.600766999999999) 18010
# 438282               (31.7945578, 35.2414009)
# 438283        (51.3781162, -2.3272635) BA2 7AY
# 438284  (59.36276469999999, 18.0592677) 114 18
# 438285          (43.3309433, -2.9678921) 48940
# 438286            (48.8471036, 2.357499) 75005
# 438287         (42.2780436, -83.7382241) 48109
# 438288         (29.6436325, -82.3549302) 32611
# 438289         (29.6436325, -82.3549302) 32611
# 438290         (41.8267718, -71.4025482) 02912
# 438291  (38.9076089, -77.07225849999999) 20057
# 438292          (40.4443533, -79.960835) 15260
# 438293         (46.8977528, -96.8024367) 58105
# 438294              (40.1019523, -88.2271615)
# 438295         (37.4274745, -122.169719) 94305
# 438296         (29.6436325, -82.3549302) 32611
# 438297  (42.0564594, -87.67526699999999) 60208
# 438298        (32.2318851, -110.9501094) 85721
# 438299        (34.4125224, -109.4106732) 85936
#
# [438300 rows x 16 columns]

# %%
# pickle_name='/home/juliaponcela/at_NICO/Dropbox_collaboration_patterns/Results/new_dict_user_id_user_attr_PARTIAL.pickle'
# with open(pickle_name, 'rb') as handle:
#     dict_user_id_user_attr = pickle.load(handle)
# print "num. folders:",len(dict_user_id_user_attr)
# #######################################################

# %%
len(dict_user_id_user_attr)

# 629145600.0: {'Country': 'United States',
#   'University_name': 'cornell university',
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 0,
#   'email_domain': 'cornell.edu',
#   'field': nan,
#   'folders_above_avg': {1369112819.0: 0},
#   'geoloc': '(42.4534492, -76.4735027) 14850',
#   'gini_act_across_folders': nan,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 8.0,
#   'number_folders': 1,
#   'user_id': 629145600.0,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 10.0,
#   'world_ranking': 10.0},

# %%
# dict_user_id_user_attr
# 629145600.0: {'Country': 'United States',
#   'University_name': 'cornell university',
#   'career_stage': nan,
#   'category_total_cit': nan,
#   'category_total_last_auth': nan,
#   'category_total_publ': nan,
#   'eff_num_folders': 0,
#   'email_domain': 'cornell.edu',
#   'field': nan,
#   'geoloc': '(42.4534492, -76.4735027) 14850',
#   'gini_act_across_folders': nan,
#   'group_num_citations': nan,
#   'group_num_papers_last': nan,
#   'group_total_publ': nan,
#   'national_ranking': 8.0,
#   'number_folders': 1,
#   'user_id': 629145600,
#   'user_tot_act': 0.0,
#   'user_tot_num_adds': 0.0,
#   'user_tot_num_deletes': 0.0,
#   'user_tot_num_edits': 0.0,
#   'user_univ_ranking': 10.0,
#   'world_ranking': '10'},

# %%
########### i get dict for the folder_id attr.



def grouping_folder(folder_id, dict_folder_id_folder_attr, df_select_folder_act, df_select_users_attr, list_users):  # df_select_folder_act is sorted by user_id and then date
   
   
    
    dict_folder_id_folder_attr[folder_id]={}
    
    dict_folder_id_folder_attr[folder_id]["number_active_members"]=len(list_users)
   
    
    
    list_users_projects=[]
    for user_id in list_users:
        list_users_projects += dict_user_id_list_folders[user_id]
        
    dict_folder_id_folder_attr[folder_id]["num_unique_projects_members_work_on"]=len(list(set(list_users_projects)))  # total "experience" of the team
    
                        
    
    
    
   
  
    folder_lifespan=1          # the selected dataframe is sorted by date already       
    try:        
        folder_lifespan= (df_select_folder_act.date.iloc[-1] -  df_select_folder_act.folder_creation_date.iloc[0]).days +1       
       
    except  AttributeError:   # in case the last dates happen to be NAN or NaT:  # in case the last date happens to be NAN, then i look for the last non-nan date available
    
        cont=1
        index=-2
        while cont <= len(df_select_folder_act) :
            try:
                folder_lifespan= (df_select_folder_act.date.iloc[index] -  df_select_folder_act.folder_creation_date.iloc[0]).days +1         
                cont = 10000000
            except : 
                index -=1

            cont +=1               
            
    dict_folder_id_folder_attr[folder_id]["folder_lifespan"]=folder_lifespan
   


            
    act_period=1   # because the creation date of most folders is years before our observation period        
    try:       
        act_period= (df_select_folder_act.date.iloc[-1] -  df_select_folder_act.date.iloc[0]).days +1
    except  AttributeError:  # in case the last dates happen to be NAN
    
        cont=1
        index=-2
        while cont <= len(df_select_folder_act) :
            try:
                act_period= (df_select_folder_act.date.iloc[index] -  df_select_folder_act.date.iloc[0]).days +1               
                cont = 10000000
            except : 
                index -=1

            cont +=1          
                                                            
    dict_folder_id_folder_attr[folder_id]["act_period"]=act_period    
    
    
     
        
    
    old_list_univ_rankings=remove_nans_for_strings(list(df_select_users_attr.world_ranking))    #ojo!!! rankings are str!!    
    list_univ_rankings = [float(i) for i in old_list_univ_rankings]   
    dict_folder_id_folder_attr[folder_id]["folder_univ_median_ranking"]=np.median(list_univ_rankings)
    dict_folder_id_folder_attr[folder_id]["folder_univ_SD_ranking"]=np.std(list_univ_rankings)
    dict_folder_id_folder_attr[folder_id]["folder_univ_mean_ranking"]=np.mean(list_univ_rankings)

   
    
    
    try:
        most_common=max(set(list_univ_rankings), key=list_univ_rankings.count)
    except:  # when empty list
        most_common=np.nan
    dict_folder_id_folder_attr[folder_id]["most_common_univ_ranking"]=most_common
    
    
    
    
                   
    lista_univ=list(df_select_users_attr.University_name.dropna().unique())       
    dict_folder_id_folder_attr[folder_id]["num_universities"]=len(lista_univ)
    
   
    dict_folder_id_folder_attr[folder_id]["num_fields"]=np.nan    
    lista_fields=list(df_select_users_attr.field.dropna().unique())
    num_fields=len(lista_fields)
    if num_fields >0:
        dict_folder_id_folder_attr[folder_id]["num_fields"]=num_fields
    
    
        
       
    lista_countr=list(df_select_users_attr.Country.dropna().unique())       
    dict_folder_id_folder_attr[folder_id]["num_countries"]=len(lista_countr)
                
   
           
        
    
    tot_act=0   
    dict_user_id_contrib={}
    for user_id in list_users:
        
        df_select_user_act= df_select_folder_act[df_select_folder_act['user_id']==user_id]
        
        num_adds=sum(remove_nans_replace_by_zeros(list(df_select_user_act.num_adds)))  # for activity, NAN=0
        num_edits=sum(remove_nans_replace_by_zeros(list(df_select_user_act.num_edits)))
        num_dels=sum(remove_nans_replace_by_zeros(list(df_select_user_act.num_dels)))
        act=num_adds+num_edits+num_dels    
                      
            
        dict_user_id_contrib[user_id] =act      
        tot_act += act
    

    
    list_tot_act_each_user_in_folder=dict_user_id_contrib.values()
    dict_folder_id_folder_attr[folder_id]["folder_activity_GINI"]=gini(list_tot_act_each_user_in_folder)
    dict_folder_id_folder_attr[folder_id]["eff_num_members"]=effective_num(list_tot_act_each_user_in_folder)
    
    
    
    
  ################THIS DOES NOT WORK!!!!!!
    max_contr=max(list_tot_act_each_user_in_folder) # size of the maximum contribution
    max_user=max(dict_user_id_contrib.iteritems(), key=operator.itemgetter(1))[1]  # user with max contribution to the folder
    
    dict_folder_id_folder_attr[folder_id]["dominated_folder"]=0
    dict_folder_id_folder_attr[folder_id]["folder_dominator"]=np.nan
    
    if max_contr > sum(sorted(list_tot_act_each_user_in_folder)[:-1]):
        dict_folder_id_folder_attr[folder_id]["dominated_folder"]=1
        dict_folder_id_folder_attr[folder_id]["folder_dominator"]=max_user
  ################
    
    
    
    
    
    
    tot_num_adds=sum(remove_nans_replace_by_zeros(list(df_select_folder_act.num_adds)))
    dict_folder_id_folder_attr[folder_id]["folder_tot_num_adds"]=tot_num_adds
    
    
    tot_num_edits=sum(remove_nans_replace_by_zeros(list(df_select_folder_act.num_edits)))
    dict_folder_id_folder_attr[folder_id]["folder_tot_num_edits"]=tot_num_edits
    
        
    tot_num_dels=sum(remove_nans_replace_by_zeros(list(df_select_folder_act.num_dels)))
    dict_folder_id_folder_attr[folder_id]["folder_tot_num_dels"]=tot_num_dels
    
    
    num_tot_act=tot_num_adds+tot_num_edits+tot_num_dels
    dict_folder_id_folder_attr[folder_id]["folder_tot_act"]=num_tot_act
    
    
   
    
    
    
    lista_careers=remove_nans_for_strings(list(df_select_users_attr.career_stage))  
   
    try:
        most_common=max(set(lista_careers), key=lista_careers.count)
    except ValueError:  # when empty list
        most_common=np.nan
    dict_folder_id_folder_attr[folder_id]["most_common_career_stage"]=most_common
    
    
    try:    
        dict_folder_id_folder_attr[folder_id]["fraction_SR"]=lista_careers.count("sr")/float(len(lista_careers))
    except ZeroDivisionError:
        dict_folder_id_folder_attr[folder_id]["fraction_SR"]=np.nan
    
    
    
    
             
    
    sr_users=list(df_select_users_attr[df_select_users_attr['career_stage'] == "sr"].user_id.dropna().unique())
    df_select_sr_act= df_select_folder_act[df_select_folder_act.user_id.isin(sr_users)]
    
    act_sr=sum(remove_nans_replace_by_zeros(list(df_select_sr_act.num_dels))) +\
    sum(remove_nans_replace_by_zeros(list(df_select_sr_act.num_edits)))+ \
    sum(remove_nans_replace_by_zeros(list(df_select_sr_act.num_adds)))
    try:
        dict_folder_id_folder_attr[folder_id]["fraction_work_by_SR"]=  act_sr/float(tot_act)
    except ZeroDivisionError:    
        dict_folder_id_folder_attr[folder_id]["fraction_work_by_SR"]= np.nan
        
        
   
    if lista_careers.count("sr")==0:
        dict_folder_id_folder_attr[folder_id]["fraction_work_by_SR"]= np.nan
    
   
    
    
    
     
        
 
    lista=remove_nans(list(df_select_users_attr.category_total_publ))
    try:
        most_common=max(set(lista), key=lista.count)
    except ValueError:  # empty list
        most_common=np.nan
    dict_folder_id_folder_attr[folder_id]["most_common_categ_num_publ"]=most_common
    
    
  
    lista=remove_nans(list(df_select_users_attr.category_total_last_auth))
    try:
        most_common=max(set(lista), key=lista.count)
    except ValueError:  # empty list
        most_courmmon=np.nan
    dict_folder_id_folder_attr[folder_id]["most_common_categ_num_last_auth"]=most_common
   
    
     
    lista=remove_nans(list(df_select_users_attr.category_total_cit))
    try:
        most_common=max(set(lista), key=lista.count)
    except ValueError:  # empty list
        most_common=np.nan
    dict_folder_id_folder_attr[folder_id]["most_common_num_cit"]=most_common

    
    
    
    
    
    try:
        dict_folder_id_folder_attr[folder_id]['ratio_cit_publ']=dict_folder_id_folder_attr[folder_id]['most_common_num_cit'] / dict_folder_id_folder_attr[folder_id]['most_common_categ_num_publ']
        #print dict_folder_id_folder_attr_ORIGINAL[folder_id]['ratio_cit_publ'], dict_folder_id_folder_attr_ORIGINAL[folder_id]['most_common_num_cit'] , dict_folder_id_folder_attr_ORIGINAL[folder_id]['most_common_categ_num_publ']
    
    except:
        dict_folder_id_folder_attr[folder_id]['ratio_cit_publ']=np.nan



    ########## avg geo. distance among members of the team:                     
    lista_members=dict_folder_id_list_users[folder_id]
    
    if len(lista_members)>1:
        
        list_diff_loc=list(df_select_users_attr.geoloc.dropna().unique())
        
        if len(list_diff_loc)>1:
    
            lista_pares=itertools.combinations(lista_members, 2)        
            lista_dist_pairs=[]
            
#             print df_select_users_attr
#             print 
            dict_user_geol=pd.Series(df_select_users_attr.geoloc.values,index=df_select_users_attr.user_id).to_dict()  # i get a dict from two columns
            #print dict_user_geol
           
            for pair in lista_pares:
                user1=pair[0]
                user2=pair[1]
           
                list_coord=[]
                for user in [user1, user2]:
                    #coord=df_select_users_attr[df_select_users_attr["user_id"]== user].geoloc.iloc[0] #  Examples: '(40.4428081, -79.94301279999999) 15213'  or just: '(40.4428081, -79.94301279999999)'
                    coord=dict_user_geol[user]
#                     print "user",user, "  old:",coord, "  new:",coord_bis
#                     raw_input()
                    try:
                        coord=coord.replace("(","").replace(")","").replace(", ",",").split(" ")[0]
                        lon=float(coord.split(",")[0])
                        lat=float(coord.split(",")[1])
                        tupla=(lon, lat)
                        list_coord.append(tupla)
                    except AttributeError:  # if one user doesn't have coordenates info
                        pass
                       
    
    
    
    

                try:  # to ignore the cases when one of the users doesnt have geoloc info
                    dist_pair=geopy.distance.vincenty(list_coord[0], list_coord[1]).km            
                    lista_dist_pairs.append(dist_pair)
                except : pass

                
            dict_folder_id_folder_attr[folder_id]["avg_geo_dist_km"]=np.mean(lista_dist_pairs)
            dict_folder_id_folder_attr[folder_id]["std_geo_dist_km"]=np.std(lista_dist_pairs)
            

            
        else:  # if all users in the same geolocation
            dict_folder_id_folder_attr[folder_id]["avg_geo_dist_km"]=0.
            dict_folder_id_folder_attr[folder_id]["std_geo_dist_km"]=0.
        
        
    else:  # if only one user in the team
        dict_folder_id_folder_attr[folder_id]["avg_geo_dist_km"]=0.
        dict_folder_id_folder_attr[folder_id]["std_geo_dist_km"]=0.
    ################   
    
    
    
    
    
    ######## i count how many users in this folder are above-avg in at least one of their folders
    try:
        num_above_avg_contributors=0.
        for user_id in list_users:
            suma=sum(df_select_users_attr[user_id]["folders_above_avg"].values())  # this is a dict folder: 1 or 0 for above personal avg contributor or not
            if suma >0:
                num_above_avg_contributors +=1

        dict_folder_id_folder_attr[folder_id]["num_above_avg_contributors"] = num_above_avg_contributors   # i measure how many leaders i have in a team
    except:
        dict_folder_id_folder_attr[folder_id]["num_above_avg_contributors"]=np.nan

    
    
    
    try:
        dict_folder_id_folder_attr[folder_id]["fract_above_avg_contributors"]=dict_folder_id_folder_attr[folder_id]["num_above_avg_contributors"]/float(dict_folder_id_folder_attr[folder_id]["number_active_members"])
    except:
        dict_folder_id_folder_attr[folder_id]["fract_above_avg_contributors"]=np.nan

    
    
    
############################################
#############################################
   
    
    
    
cont=1
dict_folder_id_folder_attr={}
cont=0
for folder_id in tqdm_notebook(dict_folder_id_list_users):
    
   # if folder_id not in dict_folder_id_folder_attr:
    
        list_users=dict_folder_id_list_users[folder_id]

        df_select_folder_act=df_all_act[df_all_act['folder_id']== folder_id].sort_values(by='date')        
        df_select_users_attr= df_user_basic_attr[df_user_basic_attr.user_id.isin(list_users)]        


   
        cont +=1
        grouping_folder(folder_id, dict_folder_id_folder_attr, df_select_folder_act, df_select_users_attr, list_users)
    
     #   print folder_id
    
        if cont >= 100:
            break          
  
    
print "done"









pickle_name='/home/juliaponcela/at_NICO/Dropbox_collaboration_patterns/Results/dict_folder_id_folder_attr_new_PARTIAL.pickle'
with open(pickle_name, 'wb') as handle:
    pickle.dump(dict_folder_id_folder_attr, handle)
print "written:", pickle_name




df_from_dict = pd.DataFrame.from_dict(dict_folder_id_folder_attr,orient='index')
## add foler_id from index
df_from_dict.to_csv(pickle_name.replace("dict_",'').strip(".pickle")+".csv", sep=';')
print "written:", pickle_name.replace("dict_","").strip(".pickle")+".csv"

# %%
folder_id=659554317      #  
dict_folder_id_folder_attr[folder_id]
#dict_folder_id_folder_attr={}

# %%
df_all_act[df_all_act['folder_id'] ==  folder_id]

# %%
df_user_basic_attr[df_user_basic_attr['user_id'] == 32641460.0]

# %%
len(dict_folder_id_folder_attr)

# %%
list(dict_folder_id_folder_attr.keys())[-1]

# %%
dict_folder_id_folder_attr[216006648.0]
