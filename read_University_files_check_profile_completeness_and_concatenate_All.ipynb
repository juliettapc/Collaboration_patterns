# %%
import pandas 
import numpy as np
from tqdm import tqdm
from tqdm import tnrange, tqdm_notebook
from time import sleep
import difflib
import scipy
import operator
import difflib
from IPython.core.display import display,HTML
try:
    import cPickle as pickle     #it is faster than pickle!
except:
    import pickle
    
import unicodedata
    
 
    
display(HTML("<style>.container { width:100% !important; }</style>"))  # to make the notebook use the entire width of the browser
# Out:
# <style>.container { width:100% !important; }</style>

# %%
#for item in sorted(df['First name']):
 #   print item
#for item in df.columns:
 #   print item    
#df[0:3]
#sort= df.sort_values(['Last Name'], ascending=False)
path_linkedin_linux="/home/juliaponcela/at_NICO/Dropbox_collaboration_patterns/Data/Vinu_University_Sheets/Improved_3Feb_and_more_emails_27Feb/"
#path_linkedin_win='C:\\Users\\julietta\\Work\\Dropbox_studies\\Data\\Vinu_University_Sheets\\Improved_3Feb\\'   
path_rest_70univ_linux="/home/juliaponcela/at_NICO/Dropbox_collaboration_patterns/Data/Vinu_University_Sheets/Improved_3Feb_and_more_emails_27Feb/rest_70univ_without_linkedin_info/"

list_university_files=['1.Harvard_University_removed_duplicates.xlsx','2.University_of_Chicago_removed_duplicates.xlsx',\
'3.Stanford_University_removed_duplicates.xlsx','4.University_of_California_Berkeley_removed_duplicates.xlsx', \
'5.Massachusetts_Institute_of_Technology_removed_duplicates.xlsx','6.Johns_Hopkins_University_removed_duplicates.xlsx',\
'7.University_of_Michigan_removed_duplicates.xlsx','8.Michigan_State_University_removed_duplicates.xlsx',\
'9.Yale_University_removed_duplicates.xlsx','10.University_of_California_San_Diego_removed_duplicates.xlsx',\
'11.University_of_California_Los_Angeles_removed_duplicates.xlsx','12.Columbia_University_removed_duplicates.xlsx',\
'13.Duke_University_removed_duplicates.xlsx','14.University_of_Washington_removed_duplicates.xlsx',\
'15.Princeton_University_removed_duplicates.xlsx','16.Carnegie_Mellon_University_removed_duplicates.xlsx',\
'17.University_of_Rochester_removed_duplicates.xlsx','18.Arizona_State_University_removed_duplicates.xlsx',\
'19.Pennsylvania_State_University_removed_duplicates.xlsx','20.Cornell_University_removed_duplicates.xlsx', \
'21.New_York_University_removed_duplicates.xlsx','22.University_of_Minnesota_removed_duplicates.xlsx',\
'23.Temple_University_removed_duplicates.xlsx','24.Ohio_State_University_removed_duplicates.xlsx',\
'25.University_of_Illinois_Urbana_Champaign_removed_duplicates.xlsx','26.University_of_North_Carolina_Chapel_Hill_removed_duplicates.xlsx',\
'27.Boston_University_removed_duplicates.xlsx','28.Georgia_Institute_of_Technology_removed_duplicates.xlsx',\
'29.University_of_Southern_California_removed_duplicates.xlsx','30.Northwestern_University_removed_duplicates.xlsx']




list_70extra_univ=['17.Washington_University_Saint_Louis_removed_duplicates.xlsx','70.Rensselaer_Polytechnic_Institute_removed_duplicates.xlsx',\
'31.University_of_California_San_Francisco_removed_duplicates.xlsx','71.North_Carolina_State_University_removed_duplicates.xlsx',\
'32.University_of_California_Irvine_removed_duplicates.xlsx','72.University_of_Virginia_removed_duplicates.xlsx',\
'33.University_of_Maryland_removed_duplicates.xlsx','73.Case_Western_Reserve_University_removed_duplicates.xlsx',\
'34.University_of_California_Santa_Barbara_removed_duplicates.xlsx','74.University_of_Iowa_removed_duplicates.xlsx',\
'36.The_University_of_Texas_at_Austin_removed_duplicates.xlsx','75.University_of_Colorado_removed_duplicates.xlsx',\
'37.University_of_Wisconsin_Madison_removed_duplicates.xlsx','76.Colorado_State_University_removed_duplicates.xlsx',\
'38.University_of_Massachusetts_Boston_removed_duplicates.xlsx','77.City_University_of_New_York_removed_duplicates.xlsx',\
'39.University_of_Pittsburgh_removed_duplicates.xlsx','78.University_of_Connecticut_removed_duplicates.xlsx',\
'40.University_of_Pennsylvania_removed_duplicates.xlsx','79.Virginia_Polytechnic_Institute_and_State_University_removed_duplicates.xlsx',\
'41.Vanderbilt_University_removed_duplicates.xlsx','80.University_of_Arizona_removed_duplicates.xlsx',\
'42.University_of_California_Davis_removed_duplicates.xlsx','81.University_of_Cincinnati_removed_duplicates.xlsx',\
'43.California_Institute_of_Technology_removed_duplicates.xlsx','82.University_of_New_Mexico_removed_duplicates.xlsx',\
'44.University_of_Florida_removed_duplicates.xlsx','83.University_of_Miami_removed_duplicates.xlsx',\
'45.Rice_University_removed_duplicates.xlsx','84.Yeshiva_University_removed_duplicates.xlsx',\
'46.Northeastern_University_removed_duplicates.xlsx','85.University_of_South_Florida_removed_duplicates.xlsx',\
'47.Rutgers_The_State_University_of_New_Jersey_removed_duplicates.xlsx','86.University_of_Arkansas_removed_duplicates.xlsx',\
'48.Emory_University_removed_duplicates.xlsx','87.Florida_State_University_removed_duplicates.xlsx',\
'49.Tufts_University_removed_duplicates.xlsx','88.University_of_New_Hampshire_removed_duplicates.xlsx',\
'50.Texas_AM_University_removed_duplicates.xlsx','89.University_of_Hawaii_removed_duplicates.xlsx',\
'51.Indiana_University_Bloomington_removed_duplicates.xlsx','90.University_of_Central_Florida_removed_duplicates.xlsx',\
'52.University_of_Notre_Dame_removed_duplicates.xlsx','91.University_of_Nebraska_removed_duplicates.xlsx',\
'53.Brown_University_removed_duplicates.xlsx','92.University_of_Alabama_removed_duplicates.xlsx',\
'54.MD_Anderson_Cancer_Center_University_of_Texas_removed_duplicates.xlsx','93.University_of_Delaware_removed_duplicates.xlsx',\
'55.University_of_Vermont_removed_duplicates.xlsx','94.Drexel_University_removed_duplicates.xlsx',\
'56.Iowa_State_University_removed_duplicates.xlsx','95.Syracuse_University_removed_duplicates.xlsx',\
'58.Stony_Brook_University_removed_duplicates.xlsx','97.Oregon_Health_Science_University_removed_duplicates.xlsx',\
'60.Dartmouth_College_removed_duplicates.xlsx','98.University_at_Buffalo_removed_duplicates.xlsx',\
'61.University_of_California_Santa_Cruz_removed_duplicates.xlsx','99.George_Washington_University_removed_duplicates.xlsx',\
'62.University_of_Utah_removed_duplicates.xlsx','Georgetown_University_removed_duplicates.xlsx',\
'63.Purdue_University_removed_duplicates.xlsx','Oregon_State_University_removed_duplicates.xlsx',\
'64.University_of_California_Riverside_removed_duplicates.xlsx','Rockefeller_University_removed_duplicates.xlsx',\
'65.Baylor_College_of_Medicine_removed_duplicates.xlsx','The_University_of_Tennessee_Knoxville_removed_duplicates.xlsx',\
'68.University_of_Georgia_removed_duplicates.xlsx','University_of_Houston_removed_duplicates.xlsx',\
'69.University_of_Illinois_Chicago_removed_duplicates.xlsx','University_of_Kansas_removed_duplicates.xlsx']
    
    
    

#list_university_files=["10.University_of_California_San_Diego_removed_duplicates.xlsx","24.Ohio_State_University_removed_duplicates.xlsx","11.University_of_California_Los_Angeles_removed_duplicates.xlsx","25.University_of_Illinois_Urbana_Champaign_removed_duplicates.xlsx","12.Columbia_University_removed_duplicates.xlsx","26.University_of_North_Carolina_Chapel_Hill_removed_duplicates.xlsx","13.Duke_University_removed_duplicates.xlsx","14.University_of_Washington_removed_duplicates.xlsx","27.Boston_University_removed_duplicates.xlsx","15.Princeton_University_removed_duplicates.xlsx","28.Georgia_Institute_of_Technology_removed_duplicates.xlsx","16.Carnegie_Mellon_University_removed_duplicates.xlsx","2.University_of_Chicago_removed_duplicates.xlsx","17.University_of_Rochester_removed_duplicates.xlsx","30.Northwestern_University_removed_duplicates.xlsx","18.Arizona_State_University_removed_duplicates.xlsx","3.Stanford_University_removed_duplicates.xlsx","19.Pennsylvania_State_University_removed_duplicates.xlsx","4.University_of_California_Berkeley_removed_duplicates.xlsx","1.Harvard_University_removed_duplicates.xlsx","5.Massachusetts_Institute_of_Technology_removed_duplicates.xlsx","20.Cornell_University_removed_duplicates.xlsx","6.Johns_Hopkins_University_removed_duplicates.xlsx","21.New_York_University_removed_duplicates.xlsx","7.University_of_Michigan_removed_duplicates.xlsx","22.University_of_Minnesota_removed_duplicates.xlsx","8.Michigan_State_University_removed_duplicates.xlsx","23.Temple_University_removed_duplicates.xlsx","9.Yale_University_removed_duplicates.xlsx"]    

# list_university_files=['3.Stanford_University_removed_duplicates.xlsx']
### OJO!!! Give all files the same headers as 5.MIT has, so i can read them all automatically


#for item in df.columns:
 #   print item    

list_all_uni_files=[]
for item in list_university_files:
    item=path_linkedin_linux+item   
    list_all_uni_files.append(item)
# print ("number of files read:",len(list_university_files))



for item in list_70extra_univ:
    item=path_rest_70univ_linux+item
    list_all_uni_files.append(item)

# %%
len(list_all_uni_files)
# Out:
# 100

# %%
tot_num_unique_names=0
tot_cont_linkedin=0
tot_cont_cv=0

tot_num_emails=0
tot_num_current_pos=0
tot_num_prev_pos=0
tot_num_ed=0
tot_all_info =0  
   
tot_some_info=0    
list_df=[]



cont_files=0
dict_filenames_fract_info={}

list_headers=["firstname","lastname","Current_Title","Email","University","School/college","Department(s)","Url","CV_Url","Linkedin_Url","Starting_Year_Current_Position","Institution_Bachelors_Degree","Field_Bachelors_Degree","Years_Bachelors_Degree","Institution_Masters","Field_Masters","Years_Masters","Institution_Phd","Field_Phd","Years_Phd","Previous_Title_0","Previous_Institution_0","Years_0","Department_0","Previous_Title_1","Previous_Institution_1","Years_1","Department_1","Previous_Title_2","Previous_Institution_2","Years_2","Department_2","Previous_Title_3","Previous_Institution_3","Years_3","Department_3","Previous_Title_4","Previous_Institution_4","Years_4","Department_4","Previous_Title_5","Previous_Institution_5","Years_5","Department_5","Previous_Title_6","Previous_Institution_6","Years_6","Department_6","Previous_Title_7","Previous_Institution_7","Years_7","Department_7","Previous_Title_8","Previous_Institution_8","Years_8","Department_8","Previous_Title_9","Previous_Institution_9","Years_9","Department_9","Previous_Title_10","Previous_Institution_10","Years_10","Department_10","Previous_Title_11","Previous_Institution_11","Years_11","Department_11","Previous_Title_12","Previous_Institution_12","Years_12","Department_12","Previous_Title_13","Previous_Institution_13","Years_13","Department_13","Previous_Title_14","Previous_Institution_14","Years_14","Department_14","Previous_Title_15","Previous_Institution_15","Years_15","Department_15","Previous_Title_16","Previous_Institution_16","Years_16","Department_16","Previous_Title_17","Previous_Institution_17","Years_17","Department_17","Previous_Title_18","Previous_Institution_18","Years_18","Department_18","Previous_Title_19","Previous_Institution_19","Years_19","Department_19","Previous_Title_20","Previous_Institution_20","Years_20","Department_20","Previous_Title_21","Previous_Institution_21","Years_21","Department_21","Previous_Title_22","Previous_Institution_22","Years_22","Department_22","Previous_Title_23","Previous_Institution_23","Years_23","Department_23","Previous_Title_24","Previous_Institution_24","Years_24","Department_24","Previous_Title_25","Previous_Institution_25","Years_25","Department_25","Previous_Title_26","Previous_Institution_26","Years_26","Department_26","Previous_Title_27","Previous_Institution_27","Years_27","Department_27","Previous_Title_28","Previous_Institution_28","Years_28","Department_28","Previous_Title_29","Previous_Institution_29","Years_29","Department_29"]
   

for filename in list_all_uni_files:
    cont_files +=1
    print "\n\n",cont_files, "  ",filename
    
   
    df = pandas.read_excel(open(filename,'rb'), na_values=["nan","NaN","--","..","..."," "])
    df.columns = [col.strip() for col in df.columns]  # i remove spaces in field names
    
    
    

#            firstname	lastname	Current_Title	Email	University	School/college	Department(s)	Url	CV_Url
#         Linkedin_Url
#         Starting_Year_Current_Position	Institution_Bachelors_Degree	Field_Bachelors_Degree	
#         Years_Bachelors_Degree	Institution_Masters	Field_Masters	Years_Masters	Institution_Phd	Field_Phd	
#         Years_Phd	Previous Title_0	Previous Institution_0	Years_0	Department_0	Previous Title_1	
#         Previous Institution_1	Years_1	Department_1	Previous Title_2	Previous Institution_2	Years_2	Department_2	Previous Title_3	Previous Institution_3	Years_3	Department_3	Previous Title_4	Previous Institution_4	Years_4	Department_4	Previous Title_5	Previous Institution_5	Years_5	Department_5	Previous Title_6	Previous Institution_6	Years_6	Department_6	Previous Title_7	Previous Institution_7	Years_7	Department_7	Previous Title_8	Previous Institution_8	Years_8	Department_8	Previous Title_9	Previous Institution_9	Years_9	Department_9	Previous Title_10	Previous Institution_10	Years_10	Department_10	Previous Title_11	Previous Institution_11	Years_11	Department_11	Previous Title_12	Previous Institution_12	Years_12	Department_12	Previous Title_13	Previous Institution_13	Years_13	Department_13	Previous Title_14	Previous Institution_14	Years_14	Department_14	Previous Title_15	Previous Institution_15	Years_15	Department_15	Previous Title_16	Previous Institution_16	Years_16	Department_16	Previous Title_17	Previous Institution_17	Years_17	Department_17	Previous Title_18	Previous Institution_18	Years_18	Department_18	Previous Title_19	Previous Institution_19	Years_19	Department_19	Previous Title_20	Previous Institution_20	Years_20	Department_20	Previous Title_21	Previous Institution_21	Years_21	Department_21	Previous Title_22	Previous Institution_22	Years_22	Department_22	Previous Title_23	Previous Institution_23	Years_23	Department_23	Previous Title_24	Previous Institution_24	Years_24	Department_24	Previous Title_25	Previous Institution_25	Years_25	Department_25	Previous Title_26	Previous Institution_26	Years_26	Department_26	Previous Title_27	Previous Institution_27	Years_27	Department_27	Previous Title_28	Previous Institution_28	Years_28	Department_28	Previous Title_29	Previous Institution_29	Years_29	Department_29
              

    
    
    
    
    
    
    test = df.copy()
    

    test = test[[c for c in test.columns if not c.startswith('Unnamed')]]  # remove some extra columns
    
    indice=len(test.columns)
    test.columns = list_headers[:indice]
    
    #print len(test.columns), len(list_headers)   #160 140
    indice=len(test.columns)
    test.columns = list_headers[:indice]
    
    
   
    list_df.append(test)
   

    
    
    
    master_dict={}    
    list_for_dropping=[]
    cont =0
    cont_linkedin=0
    cont_cv=0
    num_unique_names=0    
     
    
    num_emails=0
    num_current_pos=0
    num_prev_pos=0
    num_ed=0    
    all_info =0          
    some_info =0                
        
   
    
    ##### lambda x: x if pd.isnull(x) else x.lower()
    
#     test['firstname'] = test.apply(lambda row: row.firstname .replace("."," ").replace("-","").lower(), axis=1)    
   
    #test['lastname'] = test.apply(lambda row: row.lastname .replace("."," ").replace("-","").lower(), axis=1)
    
     
    
    # reformating the names
   
    test['lastname'] =  test['lastname'].str.replace("."," ").str.replace("-","").str.strip().str.lower()
    test['firstname'] =  test['firstname'].str.replace("."," ").str.replace("-","").str.strip().str.lower()
    
    
    for index, row in test.iterrows():
       cont +=1
           # print cont
                 
        
       if   pandas.isnull(row['firstname']) == False  or   pandas.isnull(row['lastname']) == False:
        
         
        try:  # to solve some name issues like:first: Marco   last: nan  (i cant concatenate that)
            row['firstname'] + " " 
            first=row['firstname']
        except TypeError:
            first=""
            
        try:    
            row['lastname'] + " "      
            last=row['lastname']
        except TypeError:
            last =""
            
        #print  first,last,row['University']   
        try:
            name= first + " " + last + " " +row['University']
        except :
                print  first,last,row['University']   
        
        
        flag_all_info=0
        
        if name not in master_dict:   # i ignore any duplicates!
                master_dict [name] ={}
                tot_num_unique_names +=1
                num_unique_names +=1  # in the file
               

                
                linkedin= row['Linkedin_Url']
                cv_url=row['CV_Url'] 

    
                if pandas.isnull(row['Linkedin_Url']) == False and "NO_LinkedIn profile" not in linkedin:                  
                    cont_linkedin  +=1   
                    tot_cont_linkedin  +=1   
                elif pandas.isnull(row['CV_Url']) == False:    ### how to check if an element is nan                                      
                    cont_cv +=1
                    tot_cont_cv +=1

                
                       
                   
                
                
    
                if   row['Email']  != '..'  and   row['Email']  != '...'  and   row['Email']  != '--'  and   row['Email']  != '':  
                    flag_all_info  +=1
                
                
                if   pandas.isnull(row['Current_Title']) == False:
                    num_current_pos +=1 
                    tot_num_current_pos +=1 
                    
                    flag_all_info  +=1
                    
                    
                    
                    #    if   pandas.isnull(row['Starting_Year_Current_Position']) == False:
                    #  flag_some_info = 1 
                  
                
#                 if   pandas.isnull(row['Institution_Phd']) == False  or   pandas.isnull(row['Field_Phd']) == False\
#                     or pandas.isnull(row['Years_Phd']) == False:
#                         num_ed +=1
#                         tot_num_ed +=1
                
                if   pandas.isnull(row['Previous_Title_0']) == False or  pandas.isnull(row['Previous_Institution_0']) == False\
                    or pandas.isnull(row['Years_0']) == False  or pandas.isnull(row['Department_0']) == False:
                    num_prev_pos +=1
                    tot_num_prev_pos +=1
                
                    flag_all_info  +=1
                        


                if pandas.isnull(row['Institution_Bachelors_Degree']) == False or \
    pandas.isnull(row['Field_Bachelors_Degree']) == False or pandas.isnull(row['Years_Bachelors_Degree']) == False or\
    pandas.isnull(row['Institution_Masters'] ) == False or pandas.isnull(row['Field_Masters']) == False or\
    pandas.isnull(row['Years_Masters']) == False or  pandas.isnull(row['Institution_Phd']) == False or\
    pandas.isnull(row['Field_Phd']) == False or pandas.isnull(row['Years_Phd']) == False:
        
                    num_ed +=1
                    tot_num_ed +=1        
                    flag_all_info  +=1
                 
                if flag_all_info == 4:
                     all_info +=1                
                     tot_all_info +=1
                    
                    
                if flag_all_info >= 3:    
                 some_info +=1   
                 tot_some_info +=1
                
        else:
                list_for_dropping.append(index) 
                
      
     
   
    num_emails = num_unique_names-test['Email'].isnull().sum()
    tot_num_emails += num_emails
   
            
            
    N=float(len(test.values))
    print "# names before dropping",N, "  after:",  num_unique_names," with:" 
    print "# rows to be dropped: ", len(list_for_dropping)  , "  out of:",cont 
    print "    linkedIn profile:", cont_linkedin, float(cont_linkedin)/num_unique_names
    print "    cv url:", cont_cv, float(cont_cv)/num_unique_names
    print "       linkedIn   OR   cv url:", cont_cv+cont_linkedin, float(cont_cv+cont_linkedin)/num_unique_names 
   
    print "    emails:",num_emails,num_emails/ float(num_unique_names)
    print "    num_current_pos:",num_current_pos,num_current_pos/ float(num_unique_names)
    print "    num_prev_pos:",num_prev_pos, num_prev_pos/float(num_unique_names)
    print "    num_ed:",num_ed, num_ed/float(num_unique_names)
    print "      with all info in the 4 fields:", all_info, float(all_info)/float(num_unique_names)
    print "      with some info in (3 out of 4) fields:", some_info, float(some_info)/float(num_unique_names)
    
    print "-----# emails so far:",tot_num_emails,tot_num_emails/float(tot_num_unique_names)
    print "tot fract. all info (so far):", float(tot_all_info) /tot_num_unique_names
    print "# unique names(so far):", tot_num_unique_names,"\n\n\n"
          
   
    
    
    
    dict_filenames_fract_info[filename]=(num_unique_names, float(cont_linkedin)/num_unique_names, \
                        cont_linkedin, float(cont_cv)/num_unique_names, \
                        cont_cv, float(all_info)/num_unique_names, \
                        all_info, float(some_info)/float(num_unique_names), some_info,\
                        num_emails, num_emails/ float(num_unique_names),\
                        num_current_pos, num_current_pos/ float(num_unique_names), \
                        num_prev_pos, num_prev_pos/float(num_unique_names), num_ed,\
                        num_ed/float(num_unique_names) )
    

     
print "\ntot num. unique names:",tot_num_unique_names, "with:"
print "   linkedin:",tot_cont_linkedin,float(tot_cont_linkedin)/tot_num_unique_names
print "   cv url:",tot_cont_cv,float(tot_cont_cv)/tot_num_unique_names   
print "      linkedIn or cv url:", tot_cont_cv+tot_cont_linkedin, float(tot_cont_cv+tot_cont_linkedin)/tot_num_unique_names
  
print "   emails:",tot_num_emails,tot_num_emails/float(tot_num_unique_names)
print "   num_current_pos:",tot_num_current_pos,tot_num_current_pos/ float(tot_num_unique_names)
print "   num_prev_pos:",tot_num_prev_pos, tot_num_prev_pos/float(tot_num_unique_names)
print "   num_ed:",tot_num_ed, tot_num_ed/float(tot_num_unique_names)
print "      with all info in the 4 fields:", float(tot_all_info) /tot_num_unique_names, tot_all_info
print "      with all some in (3 out of 4) fields:", float(tot_some_info) /tot_num_unique_names, tot_some_info,"\n\n\n"
# Out:
# 1    /home/juliaponcela/at_NICO/Dropbox_collaboration_patterns/Data/Vinu_University_Sheets/Improved_3Feb_and_more_emails_27Feb/1.Harvard_University_removed_duplicates.xlsx
# # names before dropping 2173.0   after: 2091  with:
# # rows to be dropped:  82   out of: 2173
#     linkedIn profile: 922 0.44093735055
#     cv url: 744 0.35581061693
#        linkedIn   OR   cv url: 1666 0.79674796748
#     emails: 2073 0.991391678623
#     num_current_pos: 2025 0.96843615495
#     num_prev_pos: 920 0.439980870397
#     num_ed: 1345 0.643232902917
#       with all info in the 4 fields: 719 0.343854615017
#       with some info in (3 out of 4) fields: 1518 0.725968436155
# -----# emails so far: 2073 0.991391678623
# tot fract. all info (so far): 0.343854615017
# # unique names(so far): 2091
#
#
#
#
#
# 2    /home/juliaponcela/at_NICO/Dropbox_collaboration_patterns/Data/Vinu_University_Sheets/Improved_3Feb_and_more_emails_27Feb/2.University_of_Chicago_removed_duplicates.xlsx
# ...

# %%
### i concatenate all dataframes (they must have identical column structure!)
df_linkedin = pandas.concat(list_df, ignore_index=True)  ## OJO!! if i dont set up ignore_indx=True, then i will have REPEATED indeces 
# in the final concat. dataframe!!

print "\nsize concatenated df:",df_linkedin.shape
# Out:
# size concatenated df: (225009, 140)

# %%
df_linkedin.head(3)
# Out:
#        firstname lastname                                   Current_Title  \
# 0       nicholas  argyres                           Professor of Strategy
# 1  mariagiovanna  baccara                Associate Professor of Economics
# 2         markus     baer  Associate Professor of Organizational Behavior
#
#                 Email                         University  \
# 0   argyres@wustl.edu  Washington University in St.Louis
# 1  mbaccara@wustl.edu  Washington University in St.Louis
# 2      baer@wustl.edu  Washington University in St.Louis
#
#          School/college Department(s)  \
# 0  OLIN BUSINESS SCHOOL    Accounting
# 1  OLIN BUSINESS SCHOOL    Accounting
# 2  OLIN BUSINESS SCHOOL    Accounting
#
#                                                  Url CV_Url Linkedin_Url  \
# 0  https://olin.wustl.edu/EN-US/Faculty-Research/...    NaN          NaN
# 1  https://olin.wustl.edu/EN-US/Faculty-Research/...    NaN          NaN
# ...

# %%
def get_middle(string):    
    lista=string.split(" ")
    if len(lista)==3:                
        return lista[1]
    else:
        return ""         ###ISSUE alejandro de la fuente


def get_firstname(string):     
    #print string
    return string.split(" ")[0]


def get_firstname_initial(string):  
    try:
        return string.split(" ")[0][0]
    except:
        print string
        raw_input()



def get_lastname(string):        
    return string.split(" ")[-1]

# %%
df_linkedin.rename(columns={'firstname':'dirty_firstname'}, inplace=True) 
df_linkedin.rename(columns={'lastname':'dirty_lastname'}, inplace=True) 



df_linkedin.dirty_firstname = df_linkedin.dirty_firstname.fillna('')  # i convert NaN into empty strings, so i can concatenate them without errors
df_linkedin.dirty_lastname = df_linkedin.dirty_lastname.fillna('')




df_linkedin['full_name'] = df_linkedin['dirty_firstname'] + " "+ df_linkedin['dirty_lastname']  #harold y hwang          ###   rick john w       ###   yanagisako sylvia




df_linkedin['firstname'] = df_linkedin.full_name.apply(get_firstname)
df_linkedin['firstname_initial'] = df_linkedin.full_name.apply(get_firstname_initial)
df_linkedin['lastname'] = df_linkedin.full_name.apply(get_lastname)


df_linkedin['middle'] = df_linkedin.full_name.apply(get_middle)



### rearrange columns' order

list_headers=["dirty_firstname","dirty_lastname","full_name", "firstname","middle","lastname","Current_Title","Email","University","School/college","Department(s)","Url","CV_Url","Linkedin_Url","Starting_Year_Current_Position","Institution_Bachelors_Degree","Field_Bachelors_Degree","Years_Bachelors_Degree","Institution_Masters","Field_Masters","Years_Masters","Institution_Phd","Field_Phd","Years_Phd","Previous_Title_0","Previous_Institution_0","Years_0","Department_0","Previous_Title_1","Previous_Institution_1","Years_1","Department_1","Previous_Title_2","Previous_Institution_2","Years_2","Department_2","Previous_Title_3","Previous_Institution_3","Years_3","Department_3","Previous_Title_4","Previous_Institution_4","Years_4","Department_4","Previous_Title_5","Previous_Institution_5","Years_5","Department_5","Previous_Title_6","Previous_Institution_6","Years_6","Department_6","Previous_Title_7","Previous_Institution_7","Years_7","Department_7","Previous_Title_8","Previous_Institution_8","Years_8","Department_8","Previous_Title_9","Previous_Institution_9","Years_9","Department_9","Previous_Title_10","Previous_Institution_10","Years_10","Department_10","Previous_Title_11","Previous_Institution_11","Years_11","Department_11","Previous_Title_12","Previous_Institution_12","Years_12","Department_12","Previous_Title_13","Previous_Institution_13","Years_13","Department_13","Previous_Title_14","Previous_Institution_14","Years_14","Department_14","Previous_Title_15","Previous_Institution_15","Years_15","Department_15","Previous_Title_16","Previous_Institution_16","Years_16","Department_16","Previous_Title_17","Previous_Institution_17","Years_17","Department_17","Previous_Title_18","Previous_Institution_18","Years_18","Department_18","Previous_Title_19","Previous_Institution_19","Years_19","Department_19","Previous_Title_20","Previous_Institution_20","Years_20","Department_20","Previous_Title_21","Previous_Institution_21","Years_21","Department_21","Previous_Title_22","Previous_Institution_22","Years_22","Department_22","Previous_Title_23","Previous_Institution_23","Years_23","Department_23","Previous_Title_24","Previous_Institution_24","Years_24","Department_24","Previous_Title_25","Previous_Institution_25","Years_25","Department_25","Previous_Title_26","Previous_Institution_26","Years_26","Department_26","Previous_Title_27","Previous_Institution_27","Years_27","Department_27","Previous_Title_28","Previous_Institution_28","Years_28","Department_28","Previous_Title_29","Previous_Institution_29","Years_29","Department_29"]
 
df_linkedin = df_linkedin[list_headers]
# Out:
#  laird
#
#  hao
#
#
#
#
#
#  scott sallay
#
#  fuchs

# %%
df_linkedin.shape
# Out:
# (225009, 140)

# %%
len(df_linkedin['Email'].unique())
# Out:
# 197435

# %%
#new_file_name_linux="/home/juliaponcela/at_NICO/Dropbox_collaboration_patterns/Data/Vinu_University_Sheets/Improved_3Feb/All_linkedIn.csv"


new_file_name=path_linkedin_linux+"All_linkedIn_complete_plus70univ_without_linkedin.tsv"  ## OJO!!! ESTE CREA UNAS 300 LINEAS EXTRAS (POR SALTOS DE CARRO ERRONEOS): USAR MEJOR EL FORMATO XLSX
df_linkedin.to_csv(new_file_name, sep='\t', encoding='utf-8', columns = list_headers)

print "csv done"


df_linkedin.to_pickle(new_file_name.split(".tsv")[0]+".pickle")
  
print "pickle done"


writer = pandas.ExcelWriter(path_linkedin_linux+"All_linkedIn_complete_plus70univ_without_linkedin.xlsx", engine='xlsxwriter',options={'strings_to_urls': False})
# Convert the dataframe to an XlsxWriter Excel object.
df_linkedin.to_excel(writer, sheet_name='Sheet1')
## OJO! hay url muy largas que hacen que el sistema se cuelgue (solucion: no permitirle que las considere url, sino simplemente str)

# Close the Pandas Excel writer and output the Excel file.
writer.save()

print "xlsx done"
# Out:
# csv done
# pickle done
# xlsx done

# %%
#pandas.ExcelWriter?

# %%
df_linkedin.head(3)
# Out:
#   firstname    lastname Current_Title                               Email  \
# 0  emmanuel  akyeampong     Professor             akyeamp@fas.harvard.edu
# 1       ali       asani     Professor            aliasani@fas.harvard.edu
# 2    robert       bates     Professor  robert.bates.harvard.edu@gmail.com
# 3     robin   bernstein     Professor             rbernst@fas.harvard.edu
# 4   suzanne       blier     Professor               blier@fas.harvard.edu
#
#            University School/college                         Department(s)  \
# 0  Harvard University            NaN  African and African American Studies
# 1  Harvard University            NaN  African and African American Studies
# 2  Harvard University            NaN  African and African American Studies
# 3  Harvard University            NaN  African and African American Studies
# 4  Harvard University            NaN  African and African American Studies
#
#                                                  Url CV_Url  \
# ...

# %%
df_linkedin.shape
# Out:
# (225009, 144)

# %%
len(df_linkedin['full_name'].unique())
# Out:
# 209116

# %%
print "Ranking,University file,Num unique faculty names,fraction unique faculty names with linkedin,Num unique faculty names with linkedin,fraction unique faculty names with cv,Num unique faculty names with cv,fraction unique faculty names with all info,Num unique faculty names with all info,fraction unique faculty names with some info,Num unique faculty names with some info,Num emails,frac emails,Num current pos,fract current pos,Num prev pos,fract prev pos,Num ed,fract ed"



sorted_x = sorted(dict_filenames_fract_info.items(), key=operator.itemgetter(1))

for item in dict_filenames_fract_info:
    print item.replace(".",",").replace("_removed_duplicates","").replace("xlsx","").replace("_"," "), dict_filenames_fract_info[item][0],",",dict_filenames_fract_info[item][1],",",\
    dict_filenames_fract_info[item][2],",",dict_filenames_fract_info[item][3],",",\
    dict_filenames_fract_info[item][4],",",dict_filenames_fract_info[item][5],",",\
    dict_filenames_fract_info[item][6],",",\
    dict_filenames_fract_info[item][7],",",dict_filenames_fract_info[item][8],",",\
    dict_filenames_fract_info[item][9],",",dict_filenames_fract_info[item][10],",",\
    dict_filenames_fract_info[item][11],",",dict_filenames_fract_info[item][12],",",\
    dict_filenames_fract_info[item][13],",",dict_filenames_fract_info[item][14],",",\
    dict_filenames_fract_info[item][15],",",dict_filenames_fract_info[item][16]
# Out:
# Ranking,University file,Num unique faculty names,fraction unique faculty names with linkedin,Num unique faculty names with linkedin,fraction unique faculty names with cv,Num unique faculty names with cv,fraction unique faculty names with all info,Num unique faculty names with all info,fraction unique faculty names with some info,Num unique faculty names with some info,Num emails,frac emails,Num current pos,fract current pos,Num prev pos,fract prev pos,Num ed,fract ed
# 23,Temple University, 2238 , 0.497319034853 , 1113 , 0.434763181412 , 973 , 0.409294012511 , 916 , 0.853887399464 , 1911 , 2078 , 0.928507596068 , 2236 , 0.999106344951 , 1085 , 0.484807864164 , 1743 , 0.778820375335
# 20,Cornell University, 3774 , 0.494170641229 , 1865 , 0.121356650768 , 458 , 0.274774774775 , 1037 , 0.558823529412 , 2109 , 3408 , 0.903020667727 , 3761 , 0.996555378908 , 1520 , 0.402755696873 , 1632 , 0.432432432432
# ...

# %%
 bines=550649
# #############  this cell is the old code


# tot_num_unique_names=0

# #list_files=['TESTING_100.Yeshiva_University.xlsx']

# master_dict_filenames={}
# for filename in list_files:
#     print filename
#     df=pandas.read_csv(path+filename, sep='|',names = ['First_Name','Last_Name','Title','Email','University','School_college','Departments','Url'])
    
#     master_dict={}
#     #First name,Last name,Title,Email,University,School/college,Department(s),url
#     list_for_dropping=[]
#     cont =0

#     for index, row in df.iterrows():
#         cont +=1
#         #print index, row['Last_Name'], row['First_Name']
#         try:
#             name= str(row['First_Name']) + ' ' +str(row['Last_Name'])
#             #print name
#             if name not in master_dict:
#                 master_dict [name] ={}
#                 tot_num_unique_names +=1
#             else:
#                 list_for_dropping.append(index)                    
#         except TypeError:
#                 pass
#     print "before dropping",len(df.values)    
#     print  " # rows to be dropped: ", len(list_for_dropping)  , "  out of:",cont 
    
    
#     ######## i create a new dataframe that excludes some rows (the duplicates)
#     df2= df.drop(df.index[list_for_dropping])      #(if i only drop, df doesnt actually get modify)
    
#     print "after dropping", len(df2.values)
#     new_file_name=path+filename.split(".xlsx")[0]+"_removed_duplicates.xlsx"
#     df2.to_csv(new_file_name, sep='|', header=False, index=False)
#     print "written:", new_file_name
    
    
#     print "tot num. unique names",tot_num_unique_names,"\n\n\n"
    
#     df2=df[df.index not in list_for_dropping]
# Out:
# 3280

# %%
 bines=550649# import pandas
# path='/home/juliaponcela/at_NICO/Dropbox_collaboration_patterns/Data/Vinu_University_Sheets/100_universities_aux/'
# list_files_top30=['20.Harvard_University_removed_duplicates.xlsx',\
#  '63.University_of_Chicago_removed_duplicates.xlsx',\
#  '41.Stanford_University_removed_duplicates.xlsx',\
#  '53.University_of_California_Berkeley_removed_duplicates.xlsx',\
#  '25.Massachusetts_Institute_of_Technology_removed_duplicates.xlsx', \
#  '23.Johns_Hopkins_University_removed_duplicates.xlsx',\
#  '79.University_of_Michigan_removed_duplicates.xlsx',\
#  '26.Michigan_State_University_removed_duplicates.xlsx',\
#  '99.Yale_University_removed_duplicates.xlsx',\
#  '58.University_of_California_San_Diego_removed_duplicates.xlsx',\
#  '56.University_of_California_Los_Angeles_removed_duplicates.xlsx', \
#  '10.Columbia_University_removed_duplicates.xlsx', \
#  '14.Duke_University_removed_duplicates.xlsx', \
#  '94.University_of_Washington_removed_duplicates.xlsx', \
#  '35.Princeton_University_removed_duplicates.xlsx', \
#  '6.Carnegie_Mellon_University_removed_duplicates.xlsx', \
#  '88.University_of_Rochester_removed_duplicates.xlsx', \
#  '1.Arizona_State_University_removed_duplicates.xlsx', \
#  '34.Pennsylvania_State_University_removed_duplicates.xlsx', \
#  '11.Cornell_University_removed_duplicates.xlsx', \
#  '27.New_York_University_removed_duplicates.xlsx', \
#  '80.University_of_Minnesota_removed_duplicates.xlsx', \
#  '44.Temple_University_removed_duplicates.xlsx', \
#  '31.Ohio_State_University_removed_duplicates.xlsx', \
#  '73.University_of_Illinois_Urbana_Champaign_removed_duplicates.xlsx', \
#  '84.University_of_North_Carolina_Chapel_Hill_removed_duplicates.xlsx', \
#  '3.Boston_University_removed_duplicates.xlsx', \
#  '19.Georgia_Institute_of_Technology_removed_duplicates.xlsx', \
#  '90.University_of_Southern_California_removed_duplicates.xlsx', \
#  '30.Northwestern_University_removed_duplicates.xlsx']
# tot_num_unique_names=0
# dict_dept_number_people={}
# for filename in list_files_top30:
#     print filename
#     df=pandas.read_csv(path+filename, sep='|',names = ['First_Name','Last_Name','Title','Email','University','School_college','Departments','Url'])
    
#     master_dict={}
#     #First name,Last name,Title,Email,University,School/college,Department(s),url
#     list_for_dropping=[]
#     cont =0
    
#     for index, row in df.iterrows():
            
#             dept=""
#             cont +=1
        
#             name= str(row['First_Name']) + ' ' +str(row['Last_Name'])
#             dept=str(row['Departments']).title()
          
            
#             ###### I group departments by similarity
            
#             if "Art" in dept:
#                 dept ="Art"
            
#             elif "African" in dept:
#                 dept ="African Studies"                   
          
#             elif "Accounting" in dept:
#                  dept ="Accounting"
#             elif "Anthropology" in dept:
#                 dept ="Anthropology"
         
#             elif "Agricultural" in dept:
#                 dept ="Agriculture"
#             elif "Asian" in dept:
#                 dept ="Asian Studies"
                
#             elif "Biochemistry" in dept  or "Biophysics" in dept or "Biomedical" in dept or "Biology" in dept  or  "Molecular" in dept:
#                  dept ="Biological"
            
            

#             elif "Business" in dept:
#                   dept ="Business"

#             elif "Cancer" in dept:
#                 dept ="Cancer"

#             elif "Chemical" in dept:
#                 dept ="Chemical"
#             elif "Classics" in dept or "Latin" in dept:
#                 dept ="Classics"

#             elif "Communication" in dept:
#                 dept ="Communication"

#             elif "Comparative" in dept:
#                 dept ="Comparative Studies"

#             elif "Computer" in dept:
#                 dept ="Computer Science"

#             elif "Earth" in dept  or "Ecology" in dept:
#                 dept ="Earth Sciences and Ecology"

#             elif "Economics" in dept:
#                 dept ="Economics"

#             elif "Education" in dept:
#                 dept ="Education"
#             elif "Electrical" in dept:
#                  dept ="Electrical Engineering"

#             elif "English" in dept:
#                 dept ="English"

#             elif "Environmental" in dept:
#                 dept ="Environmental Sciences"
#             elif "Film" in dept:
#                 dept ="Film Studies"
#             elif "Food" in dept:
#                         dept ="Food"
#             elif "French" in dept  or    "Language" in dept   or  "German" in dept or    "Russian" in dept\
#             or "Romance" in dept   or  "Russian" in dept or "Slavic" in dept  or "Scandinavian" in dept\
#             or "Spanish" in dept   or     "Linguistics"  in dept   or     "Letters"  in dept   or "Languag" in dept:
#                 dept ="Languages"

#             elif "Mechanical" in dept :                                                      
#                  dept ="Mechanical"

#             elif "Health" in dept:
#                 dept ="Health"

#             elif "History" in dept:
#                 dept ="History"

#             elif "Immuno" in dept or "Epidemiology" in dept or "Microbiology" in dept :
#                 dept ="Immunology or Epidemiology or Microbiology"
                
#             elif "Industrial" in dept:
#                 dept ="Industrial"

#             elif "Information" in dept:
#                 dept ="Information"

#             elif "Law" in dept or "Legal" in dept :
#                 dept ="Law"

#             elif "Management" in dept  or "Marketing" in dept :
#                 dept ="Management or Marketing"

#             elif "Materials" in dept:
#                 dept ="Materials"

#             elif "Mathematics" in dept:
#                 dept ="Mathematics"

#             elif "Middle East" in dept  or  "Near Eastern" in dept  :
#                 dept ="Middle Eastern"
                
#             elif "Music" in dept:
#                 dept ="Music"

#             elif "Neuro" in dept or "Neuroscience" in dept  or "Obstetrics" in dept\
#             or "Ophthalmology" in dept       or "Orthopaedic" in dept  or "Otolaryngology" in dept\
#             or "Pediatric" in dept or "Pulmonary" in dept or "Radiation" in dept or "Radiology" in dept\
#             or "Anesthesia" in dept or "Cardi" in dept or "Dermatology" in dept or "Hematology" in dept\
#              or "Surg" in dept or "Transplan" in dept or "Urolo" in dept or "Vascul" in dept\
#             or "Nursing" in dept or "Nutr" in dept or "Optics" in dept or "Ortho" in dept or "Physiol" in dept\
#             or "Rehabilitation" in dept  or "Rheumatology" in dept or "Respiratory" in dept   or "Medic" in dept:
#                  dept ="Medicine"

                    
                    
                    
                    

#             elif "Pharmacology" in dept or "Pharmacy" in dept or "Pharmaceut" in dept :
#                 dept ="Pharmacology"

#             elif "Physics" in dept:
#                 dept ="Physics"
                
#             elif "Political" in dept:
#                 dept ="Political Science"
                
#             elif "Psychiatry" in dept  or "Psycho" in dept:
#                 dept ="Psychiatry or Psychology"

#             elif "Public" in dept:
#                 dept ="Public Affairs and Health"
                
#             elif "Risk" in dept:
#                 dept ="Risk"
                
#             elif "Social" in dept or "Socio" in dept :
#                 dept ="Social or Sociology"  
                
          
#             elif "Statistics" in dept:
#                 dept ="Statistics"
                
#             elif "Theater" in dept:
#                 dept ="Theater"
                
#             elif "Urban" in dept:
#                 dept ="Urban"
                
#             elif "Veterinary" in dept:
#                 dept ="Veterinary"
                
#             elif "Visual" in dept:
#                 dept ="Visual Arts"
                
#             elif "Women" in dept:
#                 dept ="Women's Studies"
                
#             elif "Writing" in dept:
#                 dept ="Writing"
#             #else :
#              #   dept="Other"

#             #print " ---->",dept
#             #raw_input()
          
            
            
            
            
#             if dept not in dict_dept_number_people:
#                 dict_dept_number_people[dept]=1.                
#             else:
#                  dict_dept_number_people[dept] +=1.  
                
#             if name not in master_dict:
#                 master_dict [name] ={}
#                 tot_num_unique_names +=1
#             else:
#                 list_for_dropping.append(index)     
                
                
                
                
#         #except TypeError:
#          #       pass
#     print "before dropping",len(df.values)    
#     print  " # rows to be dropped: ", len(list_for_dropping)  , "  out of:",cont 
    
#     #cont=0
#     #for item in df.Departments:
#      #   print item
#       #  if cont == 10:
#        #     break
#         #cont +=1
    
#     #raw_input()
    
#     ######## i create a new dataframe that excludes some rows (the duplicates)
#     #df2= df.drop(df.index[list_for_dropping])      #(if i only drop, df doesnt actually get modify)
    
#     #print "after dropping", len(df2.values)
#     #new_file_name=path+filename.split(".xlsx")[0]+"_removed_duplicates.xlsx"
#     #df2.to_csv(new_file_name, sep='|', header=False, index=False)
#     #print "written:", new_file_name
    
    
#     print "tot num. unique names",tot_num_unique_names,"\n\n\n"
    
    
    
# tot_cont=0    
# for dept in sorted(dict_dept_number_people):
#     if dict_dept_number_people[dept] >100:
#         print dept, ";",dict_dept_number_people[dept]
#         tot_cont += dict_dept_number_people[dept]
        
        
        
# print "\n\n# people in big categories:",tot_cont
